# %%
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import json
import math

# 读取处理后的数据集
X_train = pd.read_csv('data/processed/X_train.csv')
y_train = pd.read_csv('data/processed/y_train.csv')
X_valid = pd.read_csv('data/processed/X_valid.csv')
y_valid = pd.read_csv('data/processed/y_valid.csv') 
X_train_full = pd.read_csv('data/processed/X_train_full.csv') 
y_train_full = pd.read_csv('data/processed/y_train_full.csv') 
X_test = pd.read_csv('data/processed/X_test.csv')

print('数据集读取完成')
print(f'训练集大小: {X_train.shape}')
print(f'验证集大小: {X_valid.shape}')
print(f'全量训练集大小: {X_train_full.shape}')
print(f'测试集大小: {X_test.shape}')
# Out:
# 数据集读取完成
# 训练集大小: (18150, 68)
# 验证集大小: (5000, 68)
# 全量训练集大小: (25000, 68)
# 测试集大小: (10000, 68)

# %%
# 从JSON文件读取列名配置
with open('./data/columns.json', 'r') as f:
    columns_dict = json.load(f)

# 从字典中读取列名
del_cols = columns_dict['del_cols']
text_cols = columns_dict['text_cols'] 
date_cols = columns_dict['date_cols']
numeric_cols = columns_dict['numeric_cols']
log_cols = columns_dict['log_cols']
root_cols = columns_dict['root_cols']
categorical_cols = columns_dict['categorical_cols']

# 定义变换列
cat_nu_cols = ["manufactured", "curb_weight", "power", "engine_cap", "no_of_owners", "depreciation", "coe", "road_tax", "dereg_value", "mileage", "omv", "arf", "make_target_encoded", "-", "almost new car", "coe car", "consignment car", "direct owner sale", "electric cars", "hybrid cars", "imported used vehicle", "low mileage car", "opc car", "parf car", "premium ad car", "rare & exotic", "sgcarmart warranty cars", "sta evaluated car", "vintage cars", "type_of_vehicle_bus/mini bus", "type_of_vehicle_hatchback", "type_of_vehicle_luxury sedan", "type_of_vehicle_mid-sized sedan", "type_of_vehicle_mpv", "type_of_vehicle_others", "type_of_vehicle_sports car", "type_of_vehicle_stationwagon", "type_of_vehicle_suv", "type_of_vehicle_truck", "type_of_vehicle_van", "fuel_type_diesel", "fuel_type_diesel-electric", "fuel_type_electric", "fuel_type_petrol", "fuel_type_petrol-electric", "fuel_type_nan", "transmission_manual", "year", "month"]
cat_log_cols = ["manufactured", "curb_weight", "power_log", "engine_cap_log", "depreciation_log", "coe", "road_tax_log", "dereg_value_log", "mileage_log", "omv_log", "arf_log", "make_target_encoded", "-", "almost new car", "coe car", "consignment car", "direct owner sale", "electric cars", "hybrid cars", "imported used vehicle", "low mileage car", "opc car", "parf car", "premium ad car", "rare & exotic", "sgcarmart warranty cars", "sta evaluated car", "vintage cars", "type_of_vehicle_bus/mini bus", "type_of_vehicle_hatchback", "type_of_vehicle_luxury sedan", "type_of_vehicle_mid-sized sedan", "type_of_vehicle_mpv", "type_of_vehicle_others", "type_of_vehicle_sports car", "type_of_vehicle_stationwagon", "type_of_vehicle_suv", "type_of_vehicle_truck", "type_of_vehicle_van", "fuel_type_diesel", "fuel_type_diesel-electric", "fuel_type_electric", "fuel_type_petrol", "fuel_type_petrol-electric", "fuel_type_nan", "transmission_manual", "year", "month"]
cat_root_cols = ["manufactured", "curb_weight", "power_root", "engine_cap_root", "depreciation_root", "coe", "road_tax_root", "dereg_value_root", "mileage_root", "omv_root", "arf_root", "make_target_encoded", "-", "almost new car", "coe car", "consignment car", "direct owner sale", "electric cars", "hybrid cars", "imported used vehicle", "low mileage car", "opc car", "parf car", "premium ad car", "rare & exotic", "sgcarmart warranty cars", "sta evaluated car", "vintage cars", "type_of_vehicle_bus/mini bus", "type_of_vehicle_hatchback", "type_of_vehicle_luxury sedan", "type_of_vehicle_mid-sized sedan", "type_of_vehicle_mpv", "type_of_vehicle_others", "type_of_vehicle_sports car", "type_of_vehicle_stationwagon", "type_of_vehicle_suv", "type_of_vehicle_truck", "type_of_vehicle_van", "fuel_type_diesel", "fuel_type_diesel-electric", "fuel_type_electric", "fuel_type_petrol", "fuel_type_petrol-electric", "fuel_type_nan", "transmission_manual", "year", "month"]

# %% [markdown]
# ## Baseline

# %%
# 使用数值特征 + 分类特征
for li in [cat_nu_cols, cat_log_cols, cat_root_cols]:
    # Assuming 'data' is your DataFrame and 'target' is the name of your target variable
    X = X_train[li]  # Features
    y = y_train       # Target variable

    # Creating the linear regression model
    model = LinearRegression()

    # Fitting the model
    model.fit(X, y)

    # Making predictions
    y_valid_pred = model.predict(X_valid[li])

    # Calculating the performance metrics
    mse = mean_squared_error(y_valid_pred, y_valid)
    r2 = r2_score(y_valid_pred, y_valid)
    # Calculating the RMSE
    rmse = math.sqrt(mse)

    # Printing the MSE, RMSE, and R² Score
    print(f'Mean Squared Error: {mse}')
    print(f'Root Mean Squared Error: {rmse}')
    print(f'R² Score: {r2}')
# Out:
# Mean Squared Error: 2883238432.9251704
# Root Mean Squared Error: 53695.79530023901
# R² Score: 0.8240911336521936
# Mean Squared Error: 8032677933.33663
# Root Mean Squared Error: 89625.20813552753
# R² Score: 0.02666173374675751
# Mean Squared Error: 5336926720.111189
# Root Mean Squared Error: 73054.2724288675
# R² Score: 0.4540321116014323

# %% [markdown]
# ## Other ML Regression Models

# %%
from xgboost import XGBRegressor

# # 创建XGBoost模型
model = XGBRegressor(
    # 基本参数
    n_estimators=1000,        # 树的数量
    max_depth=6,              # 树的最大深度，避免过拟合
    learning_rate=0.01,       # 较小的学习率，提高模型稳定性
    
    # 防止过拟合的参数
    min_child_weight=5,       # 控制过拟合
    gamma=0.1,               # 节点分裂所需的最小损失函数下降值
    subsample=0.8,           # 随机采样训练样本的比例
    colsample_bytree=0.8,    # 随机采样特征的比例
    
    # 正则化参数
    reg_alpha=0.1,           # L1正则化
    reg_lambda=1,            # L2正则化
    
    # 其他参数
    objective='reg:squarederror',  # 回归任务
    random_state=42,
    n_jobs=-1,               # 使用所有CPU核心
    verbosity=0
)


# Assuming 'data' is your DataFrame and 'target' is the name of your target variable
X = X_train[cat_nu_cols]  # Features
y = y_train       # Target variable

# 添加早停以防止过拟合
eval_set = [(X_valid[cat_nu_cols], y_valid)]

model.fit(
    X, 
    y,
    eval_set=eval_set
)

# Making predictions
y_valid_pred = model.predict(X_valid[cat_nu_cols])

# Calculating the performance metrics
mse = mean_squared_error(y_valid_pred, y_valid)
r2 = r2_score(y_valid_pred, y_valid)
# Calculating the RMSE
rmse = math.sqrt(mse)

# Printing the MSE, RMSE, and R² Score
# print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# print(f'R² Score: {r2}')
# Out:
# [0]	validation_0-rmse:142315.79172
# [1]	validation_0-rmse:141068.99195
# [2]	validation_0-rmse:139802.93483
# [3]	validation_0-rmse:138558.04800
# [4]	validation_0-rmse:137343.66625
# [5]	validation_0-rmse:136157.88805
# [6]	validation_0-rmse:134969.11891
# [7]	validation_0-rmse:133794.88149
# [8]	validation_0-rmse:132626.02587
# [9]	validation_0-rmse:131487.07828
# [10]	validation_0-rmse:130362.56039
# [11]	validation_0-rmse:129227.38033
# [12]	validation_0-rmse:128125.81786
# [13]	validation_0-rmse:127025.29280
# [14]	validation_0-rmse:125907.00822
# [15]	validation_0-rmse:124853.71941
# [16]	validation_0-rmse:123767.21615
# [17]	validation_0-rmse:122681.79719
# [18]	validation_0-rmse:121660.83232
# [19]	validation_0-rmse:120628.46347
# [20]	validation_0-rmse:119647.20753
# [21]	validation_0-rmse:118661.73960
# [22]	validation_0-rmse:117680.42062
# [23]	validation_0-rmse:116658.98449
# [24]	validation_0-rmse:115704.17246
# [25]	validation_0-rmse:114763.44273
# [26]	validation_0-rmse:113798.52569
# [27]	validation_0-rmse:112860.48119
# [28]	validation_0-rmse:111907.70990
# [29]	validation_0-rmse:110990.38033
# [30]	validation_0-rmse:110094.20517
# [31]	validation_0-rmse:109176.07569
# [32]	validation_0-rmse:108250.36764
# [33]	validation_0-rmse:107354.76506
# [34]	validation_0-rmse:106454.84512
# [35]	validation_0-rmse:105562.98626
# [36]	validation_0-rmse:104687.55870
# [37]	validation_0-rmse:103827.14658
# [38]	validation_0-rmse:102936.45789
# [39]	validation_0-rmse:102104.76411
# [40]	validation_0-rmse:101279.46830
# [41]	validation_0-rmse:100441.34029
# [42]	validation_0-rmse:99636.90233
# [43]	validation_0-rmse:98827.55920
# [44]	validation_0-rmse:98031.12953
# [45]	validation_0-rmse:97243.27817
# [46]	validation_0-rmse:96474.89356
# [47]	validation_0-rmse:95680.91499
# [48]	validation_0-rmse:94873.44571
# [49]	validation_0-rmse:94111.90272
# [50]	validation_0-rmse:93359.31747
# [51]	validation_0-rmse:92598.18177
# [52]	validation_0-rmse:91858.76769
# [53]	validation_0-rmse:91098.62818
# [54]	validation_0-rmse:90365.29562
# [55]	validation_0-rmse:89619.22878
# [56]	validation_0-rmse:88894.44702
# [57]	validation_0-rmse:88133.77005
# [58]	validation_0-rmse:87443.93320
# [59]	validation_0-rmse:86744.65068
# [60]	validation_0-rmse:86088.92692
# [61]	validation_0-rmse:85406.01315
# [62]	validation_0-rmse:84748.51206
# [63]	validation_0-rmse:84076.50709
# [64]	validation_0-rmse:83432.52564
# [65]	validation_0-rmse:82766.17713
# [66]	validation_0-rmse:82111.93200
# [67]	validation_0-rmse:81430.93925
# [68]	validation_0-rmse:80779.96997
# [69]	validation_0-rmse:80136.70341
# [70]	validation_0-rmse:79559.71855
# [71]	validation_0-rmse:78934.99016
# [616]	validation_0-rmse:24021.83288
# [617]	validation_0-rmse:24016.45462
# [618]	validation_0-rmse:24016.65186
# [619]	validation_0-rmse:24011.37954
# [620]	validation_0-rmse:24011.28921
# [621]	validation_0-rmse:24004.00202
# [622]	validation_0-rmse:23993.00685
# [623]	validation_0-rmse:23989.94279
# [624]	validation_0-rmse:23987.29291
# [625]	validation_0-rmse:23986.28516
# [626]	validation_0-rmse:23984.75170
# [627]	validation_0-rmse:23986.47049
# [628]	validation_0-rmse:23986.29054
# [629]	validation_0-rmse:23984.15141
# [630]	validation_0-rmse:23986.76857
# [631]	validation_0-rmse:23988.15160
# [632]	validation_0-rmse:23990.38875
# [633]	validation_0-rmse:23990.13243
# [634]	validation_0-rmse:23994.12106
# [635]	validation_0-rmse:23996.95224
# [636]	validation_0-rmse:23990.62681
# [637]	validation_0-rmse:23987.27520
# [638]	validation_0-rmse:23990.36737
# [639]	validation_0-rmse:23984.97499
# [640]	validation_0-rmse:23985.15768
# [641]	validation_0-rmse:23987.00546
# [642]	validation_0-rmse:23981.44420
# [643]	validation_0-rmse:23976.12609
# [644]	validation_0-rmse:23977.22645
# [645]	validation_0-rmse:23975.68554
# [646]	validation_0-rmse:23973.36940
# [647]	validation_0-rmse:23974.31383
# [648]	validation_0-rmse:23975.28068
# [649]	validation_0-rmse:23974.09626
# [650]	validation_0-rmse:23972.43441
# [651]	validation_0-rmse:23970.63945
# [652]	validation_0-rmse:23974.30469
# [653]	validation_0-rmse:23968.60304
# [654]	validation_0-rmse:23969.71653
# [655]	validation_0-rmse:23969.73238
# [656]	validation_0-rmse:23966.39596
# [657]	validation_0-rmse:23964.35721
# [658]	validation_0-rmse:23963.91941
# [659]	validation_0-rmse:23967.21919
# [660]	validation_0-rmse:23962.81692
# [661]	validation_0-rmse:23965.16979
# [662]	validation_0-rmse:23964.62800
# [663]	validation_0-rmse:23962.41048
# [664]	validation_0-rmse:23964.32454
# [665]	validation_0-rmse:23960.92599
# [666]	validation_0-rmse:23960.67710
# [667]	validation_0-rmse:23956.85834
# [668]	validation_0-rmse:23952.76561
# [669]	validation_0-rmse:23943.25037
# [670]	validation_0-rmse:23943.39134
# [671]	validation_0-rmse:23941.31575
# [672]	validation_0-rmse:23935.19865
# [673]	validation_0-rmse:23932.54104
# [674]	validation_0-rmse:23931.00227
# [675]	validation_0-rmse:23929.70469
# [676]	validation_0-rmse:23928.38530
# [677]	validation_0-rmse:23926.73286
# [678]	validation_0-rmse:23924.71224
# [679]	validation_0-rmse:23923.04194
# [680]	validation_0-rmse:23925.85721
# [681]	validation_0-rmse:23917.71605
# [682]	validation_0-rmse:23916.73655
# [683]	validation_0-rmse:23912.71121
# [684]	validation_0-rmse:23911.57075
# [685]	validation_0-rmse:23909.07612
# [686]	validation_0-rmse:23910.88687
# [687]	validation_0-rmse:23911.81684
# [688]	validation_0-rmse:23910.38764
# [689]	validation_0-rmse:23909.02143
# [690]	validation_0-rmse:23909.92135
# [691]	validation_0-rmse:23907.11422
# [692]	validation_0-rmse:23905.85974
# [693]	validation_0-rmse:23903.80741
# [771]	validation_0-rmse:23804.86322
# [772]	validation_0-rmse:23803.70955
# [773]	validation_0-rmse:23800.14866
# [774]	validation_0-rmse:23795.35384
# [775]	validation_0-rmse:23794.65832
# [776]	validation_0-rmse:23793.06136
# [777]	validation_0-rmse:23788.33993
# [778]	validation_0-rmse:23782.63441
# [779]	validation_0-rmse:23779.61912
# [780]	validation_0-rmse:23778.15128
# [781]	validation_0-rmse:23774.71843
# [782]	validation_0-rmse:23775.72734
# [783]	validation_0-rmse:23778.23412
# [784]	validation_0-rmse:23776.04124
# [785]	validation_0-rmse:23775.46884
# [786]	validation_0-rmse:23776.07526
# [787]	validation_0-rmse:23772.88065
# [788]	validation_0-rmse:23774.17358
# [789]	validation_0-rmse:23766.61362
# [790]	validation_0-rmse:23764.43225
# [791]	validation_0-rmse:23762.37927
# [792]	validation_0-rmse:23761.93439
# [793]	validation_0-rmse:23761.57955
# [794]	validation_0-rmse:23760.86718
# [795]	validation_0-rmse:23760.95956
# [796]	validation_0-rmse:23763.02855
# [797]	validation_0-rmse:23761.09243
# [798]	validation_0-rmse:23759.57532
# [799]	validation_0-rmse:23761.08556
# [800]	validation_0-rmse:23760.76823
# [801]	validation_0-rmse:23758.65672
# [802]	validation_0-rmse:23756.68995
# [803]	validation_0-rmse:23757.05473
# [804]	validation_0-rmse:23758.29070
# [805]	validation_0-rmse:23756.40499
# [806]	validation_0-rmse:23750.99320
# [807]	validation_0-rmse:23748.05590
# [808]	validation_0-rmse:23746.52442
# [809]	validation_0-rmse:23743.18355
# [810]	validation_0-rmse:23742.30997
# [811]	validation_0-rmse:23740.76418
# [812]	validation_0-rmse:23742.77551
# [813]	validation_0-rmse:23741.83314
# [814]	validation_0-rmse:23744.23666
# [815]	validation_0-rmse:23738.98085
# [816]	validation_0-rmse:23739.00015
# [817]	validation_0-rmse:23735.96107
# [818]	validation_0-rmse:23735.05364
# [819]	validation_0-rmse:23730.73598
# [820]	validation_0-rmse:23725.93962
# [821]	validation_0-rmse:23724.33411
# [822]	validation_0-rmse:23721.97708
# [823]	validation_0-rmse:23724.21714
# [824]	validation_0-rmse:23724.96482
# [825]	validation_0-rmse:23726.65031
# [826]	validation_0-rmse:23722.41838
# [827]	validation_0-rmse:23726.23989
# [828]	validation_0-rmse:23724.63498
# [829]	validation_0-rmse:23723.82928
# [830]	validation_0-rmse:23721.79736
# [831]	validation_0-rmse:23721.69692
# [832]	validation_0-rmse:23720.49149
# [833]	validation_0-rmse:23719.03572
# [834]	validation_0-rmse:23717.72602
# [835]	validation_0-rmse:23717.39887
# [836]	validation_0-rmse:23711.48198
# [837]	validation_0-rmse:23711.80680
# [838]	validation_0-rmse:23710.90316
# [839]	validation_0-rmse:23707.06295
# [840]	validation_0-rmse:23708.59807
# [841]	validation_0-rmse:23709.34377
# [842]	validation_0-rmse:23718.16663
# [843]	validation_0-rmse:23713.75476
# [844]	validation_0-rmse:23712.97562
# [845]	validation_0-rmse:23711.71064
# [846]	validation_0-rmse:23710.45605
# [847]	validation_0-rmse:23711.78864
# [848]	validation_0-rmse:23713.34737
# [849]	validation_0-rmse:23712.52480
# [850]	validation_0-rmse:23713.21205
# [851]	validation_0-rmse:23705.86493
# [852]	validation_0-rmse:23706.20736
# [853]	validation_0-rmse:23703.97704
# [854]	validation_0-rmse:23705.63383
# [855]	validation_0-rmse:23703.09784
# [856]	validation_0-rmse:23707.99301
# [857]	validation_0-rmse:23705.88956
# [858]	validation_0-rmse:23708.22454
# [859]	validation_0-rmse:23706.05994
# [860]	validation_0-rmse:23705.67484
# [861]	validation_0-rmse:23702.34151
# [862]	validation_0-rmse:23706.01136
# [863]	validation_0-rmse:23706.53190
# [864]	validation_0-rmse:23703.50015
# [865]	validation_0-rmse:23705.02499
# [866]	validation_0-rmse:23702.96033
# [867]	validation_0-rmse:23701.44240
# [868]	validation_0-rmse:23704.39002
# [869]	validation_0-rmse:23699.43580
# [870]	validation_0-rmse:23698.56381
# [871]	validation_0-rmse:23696.26416
# [872]	validation_0-rmse:23694.67800
# [873]	validation_0-rmse:23691.33333
# [874]	validation_0-rmse:23687.20073
# [875]	validation_0-rmse:23684.26420
# [876]	validation_0-rmse:23683.79798
# [877]	validation_0-rmse:23682.58588
# [878]	validation_0-rmse:23681.69124
# [879]	validation_0-rmse:23683.95516
# [880]	validation_0-rmse:23683.04392
# [881]	validation_0-rmse:23681.60615
# [882]	validation_0-rmse:23678.60196
# [883]	validation_0-rmse:23679.70915
# [884]	validation_0-rmse:23679.54635
# [885]	validation_0-rmse:23676.79109
# [886]	validation_0-rmse:23677.75010
# [887]	validation_0-rmse:23680.41032
# [888]	validation_0-rmse:23676.47927
# [889]	validation_0-rmse:23678.49854
# [890]	validation_0-rmse:23676.00024
# [891]	validation_0-rmse:23673.72864
# [892]	validation_0-rmse:23677.57629
# [893]	validation_0-rmse:23676.46597
# [894]	validation_0-rmse:23677.45695
# [895]	validation_0-rmse:23674.97485
# [896]	validation_0-rmse:23672.85862
# [897]	validation_0-rmse:23671.70123
# [898]	validation_0-rmse:23670.71348
# [899]	validation_0-rmse:23667.66475
# [900]	validation_0-rmse:23666.34276
# [901]	validation_0-rmse:23662.20810
# [902]	validation_0-rmse:23660.14348
# [903]	validation_0-rmse:23659.26917
# [904]	validation_0-rmse:23655.69895
# [905]	validation_0-rmse:23656.39775
# [906]	validation_0-rmse:23654.29144
# [907]	validation_0-rmse:23654.54271
# [908]	validation_0-rmse:23652.75192
# [909]	validation_0-rmse:23653.08965
# [910]	validation_0-rmse:23652.52893
# [911]	validation_0-rmse:23651.95560
# [912]	validation_0-rmse:23653.08183
# [913]	validation_0-rmse:23654.16455
# [914]	validation_0-rmse:23653.22567
# [915]	validation_0-rmse:23646.70427
# [916]	validation_0-rmse:23643.88502
# [917]	validation_0-rmse:23645.68459
# [918]	validation_0-rmse:23643.06216
# [919]	validation_0-rmse:23641.05744
# [920]	validation_0-rmse:23643.33114
# [921]	validation_0-rmse:23640.60692
# [922]	validation_0-rmse:23639.98698
# [923]	validation_0-rmse:23641.61847
# [924]	validation_0-rmse:23639.16477
# [925]	validation_0-rmse:23637.28233
# [926]	validation_0-rmse:23637.23068
# [927]	validation_0-rmse:23638.99284
# [928]	validation_0-rmse:23637.06123
# [929]	validation_0-rmse:23631.45439
# [930]	validation_0-rmse:23630.98885
# [931]	validation_0-rmse:23625.95674
# [932]	validation_0-rmse:23622.73640
# [933]	validation_0-rmse:23620.92583
# [934]	validation_0-rmse:23619.52375
# [935]	validation_0-rmse:23618.49521
# [936]	validation_0-rmse:23621.42173
# [937]	validation_0-rmse:23623.38925
# [938]	validation_0-rmse:23621.57505
# [939]	validation_0-rmse:23619.28465
# [940]	validation_0-rmse:23617.55089
# [941]	validation_0-rmse:23614.04536
# [942]	validation_0-rmse:23610.81335
# [943]	validation_0-rmse:23605.31453
# [944]	validation_0-rmse:23596.95795
# [945]	validation_0-rmse:23595.75903
# [946]	validation_0-rmse:23592.91869
# [947]	validation_0-rmse:23589.00373
# [948]	validation_0-rmse:23589.50443
# [949]	validation_0-rmse:23587.28780
# [950]	validation_0-rmse:23582.81695
# [951]	validation_0-rmse:23580.51737
# [952]	validation_0-rmse:23576.19978
# [953]	validation_0-rmse:23575.63425
# [954]	validation_0-rmse:23577.81395
# [955]	validation_0-rmse:23577.56777
# [956]	validation_0-rmse:23579.54903
# [957]	validation_0-rmse:23580.29738
# [958]	validation_0-rmse:23578.96514
# [959]	validation_0-rmse:23578.77039
# [960]	validation_0-rmse:23580.73778
# [961]	validation_0-rmse:23579.89740
# [962]	validation_0-rmse:23577.89991
# [963]	validation_0-rmse:23579.24405
# [964]	validation_0-rmse:23578.89909
# [965]	validation_0-rmse:23580.17113
# [966]	validation_0-rmse:23575.63907
# [967]	validation_0-rmse:23573.36881
# [968]	validation_0-rmse:23573.05259
# [969]	validation_0-rmse:23574.53857
# [970]	validation_0-rmse:23572.34433
# [971]	validation_0-rmse:23572.48936
# [972]	validation_0-rmse:23569.60798
# [973]	validation_0-rmse:23568.27931
# [974]	validation_0-rmse:23566.25106
# [975]	validation_0-rmse:23566.82331
# [976]	validation_0-rmse:23565.74572
# [977]	validation_0-rmse:23561.24744
# [978]	validation_0-rmse:23558.41289
# [979]	validation_0-rmse:23560.84521
# [980]	validation_0-rmse:23559.38327
# [981]	validation_0-rmse:23559.56644
# [982]	validation_0-rmse:23561.07528
# [983]	validation_0-rmse:23563.88520
# [984]	validation_0-rmse:23565.67811
# [985]	validation_0-rmse:23565.71966
# [986]	validation_0-rmse:23561.87741
# [987]	validation_0-rmse:23562.37155
# [988]	validation_0-rmse:23561.57072
# [989]	validation_0-rmse:23559.41684
# [990]	validation_0-rmse:23559.01388
# [991]	validation_0-rmse:23558.36897
# [992]	validation_0-rmse:23558.09074
# [993]	validation_0-rmse:23560.58060
# [994]	validation_0-rmse:23557.81049
# [995]	validation_0-rmse:23554.81306
# [996]	validation_0-rmse:23552.43330
# [997]	validation_0-rmse:23554.10223
# [998]	validation_0-rmse:23551.88805
# [999]	validation_0-rmse:23555.25668
# Root Mean Squared Error: 23555.256324726757

# %%
import lightgbm as lgb
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.ensemble import StackingRegressor
from xgboost import XGBRegressor

# 1. LightGBM
lgb_model = lgb.LGBMRegressor(
    n_estimators=1000,
    learning_rate=0.01,
    num_leaves=31,
    max_depth=6,
    min_child_samples=20,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    verbose=-1
)

# 2. CatBoost
cat_model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.01,
    depth=6,
    l2_leaf_reg=3,
    random_seed=42,
    verbose=False
)

# 3. Stacking
base_models = [
    ('xgb', XGBRegressor(verbosity=0, random_state=42)),
    ('lgb', lgb.LGBMRegressor(verbose=-1, random_state=42)),
    ('cat', CatBoostRegressor(verbose=False, random_seed=42))
]
stacking = StackingRegressor(
    estimators=base_models,
    final_estimator=lgb.LGBMRegressor(verbose=-1),
    cv=5
)

# 4. RandomForest
rf_model = RandomForestRegressor(
    n_estimators=200,
    max_depth=15,
    min_samples_split=5,
    min_samples_leaf=2,
    n_jobs=-1,
    random_state=42
)

# 5. GradientBoosting
gb_model = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    min_samples_split=5,
    random_state=42
)

# 比较函数
def compare_models(models, X_train, y_train, X_valid, y_valid):
    results = []
    for name, model in models.items():
        print(f"训练 {name}")
        model.fit(X_train, y_train)
        y_pred = model.predict(X_valid)
        rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
        r2 = r2_score(y_valid, y_pred)
        results.append({
            'Model': name,
            'RMSE': rmse,
            'R2': r2
        })
    return pd.DataFrame(results).sort_values('RMSE')

# 比较所有模型
models = {
    'LightGBM': lgb_model,
    'CatBoost': cat_model,
    'Stacking': stacking,
    'RandomForest': rf_model,
    'GradientBoosting': gb_model,
    'XGBoost': model  # 之前定义的XGBoost模型
}

# 使用cat_log_cols特征集（通常对价格预测效果更好）
results = compare_models(models, X_train[cat_nu_cols], y_train, 
                       X_valid[cat_nu_cols], y_valid)
print("\n模型性能比较:")
print(results)
# Out:
# 训练 LightGBM
# 训练 CatBoost
# 训练 Stacking
# /opt/miniconda3/lib/python3.10/site-packages/sklearn/ensemble/_stacking.py:970: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 训练 RandomForest
# /opt/miniconda3/lib/python3.10/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 训练 GradientBoosting
# /opt/miniconda3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# 训练 XGBoost
#
# 模型性能比较:
#               Model          RMSE        R2
# 5           XGBoost  23555.256325  0.973065
# 0          LightGBM  24887.222889  0.969932
# 1          CatBoost  27791.193073  0.962506
# 2          Stacking  28904.091927  0.959443
# 3      RandomForest  28959.985562  0.959286
# 4  GradientBoosting  29832.461299  0.956796

# %% [markdown]
# ## Prediction on test set

# %%
# 选择表现最好的模型进行最终训练和预测
best_model = models['XGBoost']  # 可以根据上面的results选择最佳模型

print("使用全量数据训练最终模型...")
best_model.fit(X_train_full[cat_nu_cols], y_train_full)

print("生成测试集预测结果...")
test_predictions = best_model.predict(X_test[cat_nu_cols])

# 创建预测结果DataFrame
predictions_df = pd.DataFrame({
    'Id': range(len(test_predictions)),
    'Predicted': test_predictions
})

# 保存预测结果
predictions_df.to_csv('data/predictions.csv', index=False)
print("预测结果已保存到 data/predictions.csv")
# Out:
# 使用全量数据训练最终模型...
# 生成测试集预测结果...
# 预测结果已保存到 data/predictions.csv
