# %%
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import json
import math

# 读取处理后的数据集
X_train = pd.read_csv('data/processed/X_train.csv')
y_train = pd.read_csv('data/processed/y_train.csv')
X_valid = pd.read_csv('data/processed/X_valid.csv')
y_valid = pd.read_csv('data/processed/y_valid.csv') 
X_train_full = pd.read_csv('data/processed/X_train_full.csv') 
y_train_full = pd.read_csv('data/processed/y_train_full.csv') 
X_test = pd.read_csv('data/processed/X_test.csv')

print('数据集读取完成')
print(f'训练集大小: {X_train.shape}')
print(f'验证集大小: {X_valid.shape}')
print(f'全量训练集大小: {X_train_full.shape}')
print(f'测试集大小: {X_test.shape}')
# Out:
# 数据集读取完成
# 训练集大小: (20000, 68)
# 验证集大小: (5000, 68)
# 全量训练集大小: (25000, 68)
# 测试集大小: (10000, 68)

# %%
# 从JSON文件读取列名配置
with open('./data/columns.json', 'r') as f:
    columns_dict = json.load(f)

# 从字典中读取列名
del_cols = columns_dict['del_cols']
text_cols = columns_dict['text_cols'] 
date_cols = columns_dict['date_cols']
numeric_cols = columns_dict['numeric_cols']
log_cols = columns_dict['log_cols']
root_cols = columns_dict['root_cols']
categorical_cols = columns_dict['categorical_cols']

# 定义变换列
cat_nu_cols = ["manufactured", "curb_weight", "power", "engine_cap", "no_of_owners", "depreciation", "coe", "road_tax", "dereg_value", "mileage", "omv", "arf", "make_target_encoded", "-", "almost new car", "coe car", "consignment car", "direct owner sale", "electric cars", "hybrid cars", "imported used vehicle", "low mileage car", "opc car", "parf car", "premium ad car", "rare & exotic", "sgcarmart warranty cars", "sta evaluated car", "vintage cars", "type_of_vehicle_bus/mini bus", "type_of_vehicle_hatchback", "type_of_vehicle_luxury sedan", "type_of_vehicle_mid-sized sedan", "type_of_vehicle_mpv", "type_of_vehicle_others", "type_of_vehicle_sports car", "type_of_vehicle_stationwagon", "type_of_vehicle_suv", "type_of_vehicle_truck", "type_of_vehicle_van", "fuel_type_diesel", "fuel_type_diesel-electric", "fuel_type_electric", "fuel_type_petrol", "fuel_type_petrol-electric", "fuel_type_nan", "transmission_manual", "year", "month"]
cat_log_cols = ["manufactured", "curb_weight", "power_log", "engine_cap_log", "depreciation_log", "coe", "road_tax_log", "dereg_value_log", "mileage_log", "omv_log", "arf_log", "make_target_encoded", "-", "almost new car", "coe car", "consignment car", "direct owner sale", "electric cars", "hybrid cars", "imported used vehicle", "low mileage car", "opc car", "parf car", "premium ad car", "rare & exotic", "sgcarmart warranty cars", "sta evaluated car", "vintage cars", "type_of_vehicle_bus/mini bus", "type_of_vehicle_hatchback", "type_of_vehicle_luxury sedan", "type_of_vehicle_mid-sized sedan", "type_of_vehicle_mpv", "type_of_vehicle_others", "type_of_vehicle_sports car", "type_of_vehicle_stationwagon", "type_of_vehicle_suv", "type_of_vehicle_truck", "type_of_vehicle_van", "fuel_type_diesel", "fuel_type_diesel-electric", "fuel_type_electric", "fuel_type_petrol", "fuel_type_petrol-electric", "fuel_type_nan", "transmission_manual", "year", "month"]
cat_root_cols = ["manufactured", "curb_weight", "power_root", "engine_cap_root", "depreciation_root", "coe", "road_tax_root", "dereg_value_root", "mileage_root", "omv_root", "arf_root", "make_target_encoded", "-", "almost new car", "coe car", "consignment car", "direct owner sale", "electric cars", "hybrid cars", "imported used vehicle", "low mileage car", "opc car", "parf car", "premium ad car", "rare & exotic", "sgcarmart warranty cars", "sta evaluated car", "vintage cars", "type_of_vehicle_bus/mini bus", "type_of_vehicle_hatchback", "type_of_vehicle_luxury sedan", "type_of_vehicle_mid-sized sedan", "type_of_vehicle_mpv", "type_of_vehicle_others", "type_of_vehicle_sports car", "type_of_vehicle_stationwagon", "type_of_vehicle_suv", "type_of_vehicle_truck", "type_of_vehicle_van", "fuel_type_diesel", "fuel_type_diesel-electric", "fuel_type_electric", "fuel_type_petrol", "fuel_type_petrol-electric", "fuel_type_nan", "transmission_manual", "year", "month"]

# %% [markdown]
# ## Baseline

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

class MLPModel(nn.Module):
    def __init__(self, input_dim):
        super(MLPModel, self).__init__()
        self.layer1 = nn.Linear(input_dim, 128)
        self.layer2 = nn.Linear(128, 64)
        self.layer3 = nn.Linear(64, 32)
        self.output_layer = nn.Linear(32, 1)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        x = self.relu(self.layer1(x))
        x = self.relu(self.layer2(x))
        x = self.relu(self.layer3(x))
        x = self.output_layer(x)
        return x

# %%
def train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid, lr=0.001):
    # 损失函数和优化器
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    # 数据转换为torch.Tensor
    X_train_tensor = torch.tensor(X_train[cat_nu_cols].values, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    X_valid_tensor = torch.tensor(X_valid[cat_nu_cols].values, dtype=torch.float32)
    y_valid_tensor = torch.tensor(y_valid.values, dtype=torch.float32).view(-1, 1)

    epochs = 50
    for epoch in range(epochs):
        model.train()
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

        print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')

        model.eval()
    
        # 关闭梯度计算
        with torch.no_grad():
            y_test_pred_mlp = model(X_valid_tensor)
    
        mse_test_mlp = mean_squared_error(y_valid_tensor.numpy(), y_test_pred_mlp.numpy())
        rmse_test_mlp = np.sqrt(mse_test_mlp)
        r2_test_mlp = r2_score(y_valid_tensor.numpy(), y_test_pred_mlp.numpy())
    
        #print(f'Network Valid Mean Squared Error: {mse_test_mlp}')
        print(f'Network Valid Root Mean Squared Error: {rmse_test_mlp}')
        #print(f'Network Valid R² Score: {r2_test_mlp}')
        
input_dim = len(cat_nu_cols)
print(input_dim)
model = MLPModel(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid)
# Out:
# 49
# Epoch 1/50, Loss: 607748864.0
# Network Valid Root Mean Squared Error: 48295.9453125
# Epoch 2/50, Loss: 741855424.0
# Network Valid Root Mean Squared Error: 46138.24609375
# Epoch 3/50, Loss: 463487040.0
# Network Valid Root Mean Squared Error: 45090.375
# Epoch 4/50, Loss: 850344320.0
# Network Valid Root Mean Squared Error: 42757.08984375
# Epoch 5/50, Loss: 890156224.0
# Network Valid Root Mean Squared Error: 39826.515625
# Epoch 6/50, Loss: 344895392.0
# Network Valid Root Mean Squared Error: 38284.546875
# Epoch 7/50, Loss: 15711396864.0
# Network Valid Root Mean Squared Error: 36710.96875
# Epoch 8/50, Loss: 2077256192.0
# Epoch 43/50, Loss: 51293296.0
# Network Valid Root Mean Squared Error: 27881.74609375
# Epoch 44/50, Loss: 436452320.0
# Network Valid Root Mean Squared Error: 27880.4375
# Epoch 45/50, Loss: 182767968.0
# Network Valid Root Mean Squared Error: 29625.888671875
# Epoch 46/50, Loss: 303752672.0
# Network Valid Root Mean Squared Error: 28681.96484375
# Epoch 47/50, Loss: 247371440.0
# Network Valid Root Mean Squared Error: 33193.859375
# Epoch 48/50, Loss: 166218272.0
# Network Valid Root Mean Squared Error: 29156.76953125
# Epoch 49/50, Loss: 2151103488.0
# Network Valid Root Mean Squared Error: 27520.998046875
# Epoch 50/50, Loss: 41428048.0
# Network Valid Root Mean Squared Error: 27080.01953125

# %% [markdown]
# ## Other NN Models

# %%
input_dim = len(cat_nu_cols)
print(input_dim)
model = MLPModel(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid, 0.0005)
# Out:
# 49
# Epoch 1/50, Loss: 1244009984.0
# Network Valid Root Mean Squared Error: 50034.6640625
# Epoch 2/50, Loss: 695280128.0
# Network Valid Root Mean Squared Error: 48275.3125
# Epoch 3/50, Loss: 709139904.0
# Network Valid Root Mean Squared Error: 45900.26171875
# Epoch 4/50, Loss: 342665216.0
# Network Valid Root Mean Squared Error: 47031.33203125
# Epoch 5/50, Loss: 2849889280.0
# Network Valid Root Mean Squared Error: 44549.375
# Epoch 6/50, Loss: 1426520448.0
# Network Valid Root Mean Squared Error: 45747.2734375
# Epoch 7/50, Loss: 401597376.0
# Network Valid Root Mean Squared Error: 41804.140625
# Epoch 8/50, Loss: 377034368.0
# Network Valid Root Mean Squared Error: 41713.91796875
# Epoch 9/50, Loss: 263914176.0
# Network Valid Root Mean Squared Error: 39354.09765625
# Epoch 10/50, Loss: 267312448.0
# Network Valid Root Mean Squared Error: 38761.703125
# Epoch 11/50, Loss: 115367080.0
# Network Valid Root Mean Squared Error: 39302.4453125
# Epoch 12/50, Loss: 1177873920.0
# Network Valid Root Mean Squared Error: 37432.46484375
# Epoch 13/50, Loss: 485543520.0
# Network Valid Root Mean Squared Error: 36411.62890625
# Epoch 14/50, Loss: 464420736.0
# Network Valid Root Mean Squared Error: 51423.640625
# Epoch 15/50, Loss: 2456994304.0
# Network Valid Root Mean Squared Error: 34577.57421875
# Epoch 16/50, Loss: 316625632.0
# Network Valid Root Mean Squared Error: 34746.80859375
# Epoch 17/50, Loss: 267614320.0
# Network Valid Root Mean Squared Error: 33046.60546875
# Epoch 18/50, Loss: 846548736.0
# Network Valid Root Mean Squared Error: 32127.576171875
# Epoch 19/50, Loss: 523775264.0
# Network Valid Root Mean Squared Error: 32661.30859375
# Epoch 20/50, Loss: 194972656.0
# Network Valid Root Mean Squared Error: 31993.5390625
# Epoch 21/50, Loss: 1597834240.0
# Network Valid Root Mean Squared Error: 36161.578125
# Epoch 22/50, Loss: 848045056.0
# Network Valid Root Mean Squared Error: 37706.0234375
# Epoch 23/50, Loss: 832873024.0
# Network Valid Root Mean Squared Error: 33814.81640625
# Epoch 24/50, Loss: 199644752.0
# Network Valid Root Mean Squared Error: 32015.01171875
# Epoch 25/50, Loss: 243811600.0
# Network Valid Root Mean Squared Error: 39563.96484375
# Epoch 26/50, Loss: 1019459328.0
# Network Valid Root Mean Squared Error: 31771.51953125
# Epoch 27/50, Loss: 655099008.0
# Network Valid Root Mean Squared Error: 32318.01171875
# Epoch 28/50, Loss: 1257464192.0
# Network Valid Root Mean Squared Error: 30575.37109375
# Epoch 29/50, Loss: 2424863744.0
# Network Valid Root Mean Squared Error: 34286.21875
# Epoch 30/50, Loss: 707244864.0
# Network Valid Root Mean Squared Error: 33413.875
# Epoch 31/50, Loss: 187910480.0
# Network Valid Root Mean Squared Error: 33541.53125
# Epoch 32/50, Loss: 734434240.0
# Network Valid Root Mean Squared Error: 30423.5546875
# Epoch 33/50, Loss: 633383808.0
# Network Valid Root Mean Squared Error: 29599.431640625
# Epoch 34/50, Loss: 94365280.0
# Network Valid Root Mean Squared Error: 30504.732421875
# Epoch 35/50, Loss: 195444944.0
# Network Valid Root Mean Squared Error: 29627.255859375
# Epoch 36/50, Loss: 634530304.0
# Network Valid Root Mean Squared Error: 32165.86328125
# Epoch 37/50, Loss: 253103056.0
# Network Valid Root Mean Squared Error: 31350.02734375
# Epoch 38/50, Loss: 196995360.0
# Network Valid Root Mean Squared Error: 29279.3359375
# Epoch 39/50, Loss: 284691488.0
# Network Valid Root Mean Squared Error: 30756.88671875
# Epoch 40/50, Loss: 200863248.0
# Network Valid Root Mean Squared Error: 30263.6015625
# Epoch 41/50, Loss: 716585024.0
# Network Valid Root Mean Squared Error: 29470.28515625
# Epoch 42/50, Loss: 490134272.0
# Network Valid Root Mean Squared Error: 30855.126953125
# Epoch 43/50, Loss: 1890184064.0
# Network Valid Root Mean Squared Error: 33516.6875
# Epoch 44/50, Loss: 243747520.0
# Network Valid Root Mean Squared Error: 27879.2734375
# Epoch 45/50, Loss: 1072157952.0
# Network Valid Root Mean Squared Error: 42694.0859375
# Epoch 46/50, Loss: 190614656.0
# Network Valid Root Mean Squared Error: 31570.021484375
# Epoch 47/50, Loss: 97072248.0
# Network Valid Root Mean Squared Error: 28008.78125
# Epoch 48/50, Loss: 151002816.0
# Network Valid Root Mean Squared Error: 28683.990234375
# Epoch 49/50, Loss: 500495488.0
# Network Valid Root Mean Squared Error: 28046.52734375
# Epoch 50/50, Loss: 241478544.0
# Network Valid Root Mean Squared Error: 27475.171875

# %%
class DeeperMLPModel(nn.Module):
    def __init__(self, input_dim):
        super(DeeperMLPModel, self).__init__()
        # Increasing the depth with more layers
        self.layer1 = nn.Linear(input_dim, 256)
        self.layer2 = nn.Linear(256, 128)
        self.layer3 = nn.Linear(128, 128)
        self.layer4 = nn.Linear(128, 64)
        self.layer5 = nn.Linear(64, 64)
        self.layer6 = nn.Linear(64, 32)
        self.layer7 = nn.Linear(32, 16)
        self.output_layer = nn.Linear(16, 1)
        
        # ReLU activation
        self.relu = nn.ReLU()
        
        # Initializing weights with Kaiming initialization suitable for ReLU
        self._initialize_weights()

    def forward(self, x):
        x = self.relu(self.layer1(x))
        x = self.relu(self.layer2(x))
        x = self.relu(self.layer3(x))
        x = self.relu(self.layer4(x))
        x = self.relu(self.layer5(x))
        x = self.relu(self.layer6(x))
        x = self.relu(self.layer7(x))
        x = self.output_layer(x)
        return x
    
    def _initialize_weights(self):
        # Apply Kaiming He initialization to all linear layers in the model
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                if m.bias is not None:
                    m.bias.data.fill_(0.01)

input_dim = len(cat_nu_cols)
print(input_dim)
model = DeeperMLPModel(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid)
# Out:
# 49
# Epoch 1/50, Loss: 238669056.0
# Network Valid Root Mean Squared Error: 46417.55859375
# Epoch 2/50, Loss: 8387710464.0
# Network Valid Root Mean Squared Error: 45679.55078125
# Epoch 3/50, Loss: 3386553856.0
# Network Valid Root Mean Squared Error: 41511.38671875
# Epoch 4/50, Loss: 605278016.0
# Network Valid Root Mean Squared Error: 36053.1796875
# Epoch 5/50, Loss: 648258112.0
# Network Valid Root Mean Squared Error: 35183.30078125
# Epoch 6/50, Loss: 464052448.0
# Network Valid Root Mean Squared Error: 34837.453125
# Epoch 7/50, Loss: 494918464.0
# Network Valid Root Mean Squared Error: 35201.1015625
# Epoch 8/50, Loss: 918542464.0
# Network Valid Root Mean Squared Error: 35367.4765625
# Epoch 9/50, Loss: 726468224.0
# Network Valid Root Mean Squared Error: 31921.751953125
# Epoch 10/50, Loss: 749561856.0
# Network Valid Root Mean Squared Error: 32754.83984375
# Epoch 11/50, Loss: 436575136.0
# Network Valid Root Mean Squared Error: 34722.421875
# Epoch 12/50, Loss: 1458785152.0
# Network Valid Root Mean Squared Error: 43411.43359375
# Epoch 13/50, Loss: 462579200.0
# Network Valid Root Mean Squared Error: 29898.791015625
# Epoch 14/50, Loss: 940796288.0
# Network Valid Root Mean Squared Error: 34475.8359375
# Epoch 15/50, Loss: 4425439744.0
# Network Valid Root Mean Squared Error: 30537.59375
# Epoch 16/50, Loss: 86130616.0
# Network Valid Root Mean Squared Error: 30137.078125
# Epoch 17/50, Loss: 5039134720.0
# Network Valid Root Mean Squared Error: 33189.16796875
# Epoch 18/50, Loss: 948470400.0
# Network Valid Root Mean Squared Error: 32537.86328125
# Epoch 19/50, Loss: 62646568.0
# Network Valid Root Mean Squared Error: 30760.6796875
# Epoch 20/50, Loss: 120565640.0
# Network Valid Root Mean Squared Error: 28508.41796875
# Epoch 21/50, Loss: 663022592.0
# Network Valid Root Mean Squared Error: 27052.720703125
# Epoch 22/50, Loss: 750217920.0
# Network Valid Root Mean Squared Error: 27931.01171875
# Epoch 23/50, Loss: 1505013760.0
# Network Valid Root Mean Squared Error: 29597.13671875
# Epoch 24/50, Loss: 717988672.0
# Network Valid Root Mean Squared Error: 26953.10546875
# Epoch 25/50, Loss: 60143968.0
# Network Valid Root Mean Squared Error: 27954.34765625
# Epoch 26/50, Loss: 2644088320.0
# Network Valid Root Mean Squared Error: 40081.96875
# Epoch 27/50, Loss: 142529280.0
# Network Valid Root Mean Squared Error: 28517.904296875
# Epoch 28/50, Loss: 78488704.0
# Network Valid Root Mean Squared Error: 27070.412109375
# Epoch 29/50, Loss: 1609073152.0
# Network Valid Root Mean Squared Error: 26881.318359375
# Epoch 30/50, Loss: 2314839040.0
# Network Valid Root Mean Squared Error: 25988.5078125
# Epoch 31/50, Loss: 133868928.0
# Network Valid Root Mean Squared Error: 29720.525390625
# Epoch 32/50, Loss: 165777856.0
# Network Valid Root Mean Squared Error: 25628.8515625
# Epoch 33/50, Loss: 1476435456.0
# Network Valid Root Mean Squared Error: 27968.921875
# Epoch 34/50, Loss: 135380272.0
# Network Valid Root Mean Squared Error: 25895.091796875
# Epoch 35/50, Loss: 819380864.0
# Network Valid Root Mean Squared Error: 27816.384765625
# Epoch 36/50, Loss: 153485024.0
# Network Valid Root Mean Squared Error: 28406.3515625
# Epoch 37/50, Loss: 120038240.0
# Network Valid Root Mean Squared Error: 33332.2734375
# Epoch 38/50, Loss: 263649888.0
# Network Valid Root Mean Squared Error: 32191.345703125
# Epoch 39/50, Loss: 395711040.0
# Network Valid Root Mean Squared Error: 27509.412109375
# Epoch 40/50, Loss: 550901184.0
# Network Valid Root Mean Squared Error: 36155.7578125
# Epoch 41/50, Loss: 304654720.0
# Network Valid Root Mean Squared Error: 27336.908203125
# Epoch 42/50, Loss: 163428400.0
# Network Valid Root Mean Squared Error: 33004.33984375
# Epoch 43/50, Loss: 458819776.0
# Network Valid Root Mean Squared Error: 27200.32421875
# Epoch 44/50, Loss: 54047244.0
# Network Valid Root Mean Squared Error: 25833.41015625
# Epoch 45/50, Loss: 521521472.0
# Network Valid Root Mean Squared Error: 28042.654296875
# Epoch 46/50, Loss: 1086695680.0
# Network Valid Root Mean Squared Error: 25809.564453125
# Epoch 47/50, Loss: 77543864.0
# Network Valid Root Mean Squared Error: 27458.451171875
# Epoch 48/50, Loss: 797952448.0
# Network Valid Root Mean Squared Error: 27745.8359375
# Epoch 49/50, Loss: 87764808.0
# Network Valid Root Mean Squared Error: 26382.396484375
# Epoch 50/50, Loss: 107137560.0
# Network Valid Root Mean Squared Error: 24489.09765625

# %%
input_dim = len(cat_nu_cols)
print(input_dim)
model = DeeperMLPModel(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid, 0.0001)
# Out:
# 49
# Epoch 1/50, Loss: 660415808.0
# Network Valid Root Mean Squared Error: 47059.23046875
# Epoch 2/50, Loss: 405663488.0
# Network Valid Root Mean Squared Error: 42398.02734375
# Epoch 3/50, Loss: 709602240.0
# Network Valid Root Mean Squared Error: 41479.63671875
# Epoch 4/50, Loss: 73629872.0
# Network Valid Root Mean Squared Error: 40655.3984375
# Epoch 5/50, Loss: 934678592.0
# Network Valid Root Mean Squared Error: 34870.49609375
# Epoch 6/50, Loss: 263358976.0
# Network Valid Root Mean Squared Error: 34588.28125
# Epoch 7/50, Loss: 713655104.0
# Network Valid Root Mean Squared Error: 33697.5546875
# Epoch 8/50, Loss: 279689536.0
# Network Valid Root Mean Squared Error: 37912.296875
# Epoch 9/50, Loss: 274044672.0
# Network Valid Root Mean Squared Error: 31179.0234375
# Epoch 10/50, Loss: 193827856.0
# Network Valid Root Mean Squared Error: 31457.990234375
# Epoch 11/50, Loss: 1256726656.0
# Network Valid Root Mean Squared Error: 30391.701171875
# Epoch 12/50, Loss: 488639616.0
# Network Valid Root Mean Squared Error: 31082.927734375
# Epoch 47/50, Loss: 176655376.0
# Network Valid Root Mean Squared Error: 28389.634765625
# Epoch 48/50, Loss: 213217776.0
# Network Valid Root Mean Squared Error: 28374.3203125
# Epoch 49/50, Loss: 129670344.0
# Network Valid Root Mean Squared Error: 25853.482421875
# Epoch 50/50, Loss: 303149728.0
# Network Valid Root Mean Squared Error: 30291.814453125

# %%
class DeepResidualMLP(nn.Module):
    def __init__(self, input_dim):
        super(DeepResidualMLP, self).__init__()
        self.layer1 = nn.Linear(input_dim, 256)
        self.layer2 = nn.Linear(256, 256)
        self.layer3 = nn.Linear(256, 256)
        self.layer4 = nn.Linear(256, 256)
        self.layer5 = nn.Linear(256, 256)
        self.output_layer = nn.Linear(256, 1)
        
        # ReLU activation
        self.relu = nn.ReLU()
        
        # Initializing weights with He initialization suitable for ReLU
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')

    def forward(self, x):
        identity = x
        x = self.relu(self.layer1(x))
        
        # Residual block 1
        out = self.relu(self.layer2(x))
        x = out + x  # Changed from 'out += x' to 'x = out + x'
    
        # Residual block 2
        out = self.relu(self.layer3(x))
        x = out + x  # Changed from 'x += out' to 'x = out + x'
    
        # Residual block 3
        out = self.relu(self.layer4(x))
        x = out + x  # Changed from 'out += x' to 'x = out + x'
    
        # Residual block 4
        out = self.relu(self.layer5(x))
        x = out + x  # Changed from 'x += out' to 'x = out + x'
    
        x = self.output_layer(x)
        return x


input_dim = len(cat_nu_cols)
print(input_dim)
model = DeepResidualMLP(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid)
# Out:
# 49
# Epoch 1/50, Loss: 8230856704.0
# Network Valid Root Mean Squared Error: 152490.828125
# Epoch 2/50, Loss: 448840832.0
# Network Valid Root Mean Squared Error: 41769.66015625
# Epoch 3/50, Loss: 872214592.0
# Network Valid Root Mean Squared Error: 37724.640625
# Epoch 4/50, Loss: 654452416.0
# Network Valid Root Mean Squared Error: 43114.01953125
# Epoch 5/50, Loss: 1007332608.0
# Network Valid Root Mean Squared Error: 36842.6171875
# Epoch 6/50, Loss: 824398272.0
# Network Valid Root Mean Squared Error: 38666.828125
# Epoch 7/50, Loss: 431981120.0
# Network Valid Root Mean Squared Error: 35677.109375
# Epoch 8/50, Loss: 1682814720.0
# Network Valid Root Mean Squared Error: 32295.369140625
# Epoch 9/50, Loss: 294976576.0
# Network Valid Root Mean Squared Error: 32825.45703125
# Epoch 10/50, Loss: 347056000.0
# Network Valid Root Mean Squared Error: 31785.64453125
# Epoch 11/50, Loss: 241114240.0
# Network Valid Root Mean Squared Error: 35083.66015625
# Epoch 12/50, Loss: 132194160.0
# Network Valid Root Mean Squared Error: 35768.796875
# Epoch 13/50, Loss: 145471056.0
# Network Valid Root Mean Squared Error: 33961.734375
# Epoch 14/50, Loss: 377471104.0
# Network Valid Root Mean Squared Error: 30229.74609375
# Epoch 15/50, Loss: 292731104.0
# Network Valid Root Mean Squared Error: 31162.927734375
# Epoch 16/50, Loss: 402069568.0
# Network Valid Root Mean Squared Error: 43116.33984375
# Epoch 17/50, Loss: 671611200.0
# Network Valid Root Mean Squared Error: 33583.61328125
# Epoch 18/50, Loss: 191881696.0
# Network Valid Root Mean Squared Error: 27863.59765625
# Epoch 19/50, Loss: 174272768.0
# Network Valid Root Mean Squared Error: 30157.734375
# Epoch 20/50, Loss: 132430552.0
# Network Valid Root Mean Squared Error: 27195.84375
# Epoch 21/50, Loss: 384053568.0
# Network Valid Root Mean Squared Error: 30674.251953125
# Epoch 22/50, Loss: 74455232.0
# Network Valid Root Mean Squared Error: 29257.41796875
# Epoch 23/50, Loss: 198903056.0
# Network Valid Root Mean Squared Error: 26759.576171875
# Epoch 24/50, Loss: 567593024.0
# Network Valid Root Mean Squared Error: 27191.876953125
# Epoch 25/50, Loss: 135238704.0
# Network Valid Root Mean Squared Error: 30282.859375
# Epoch 26/50, Loss: 226680848.0
# Network Valid Root Mean Squared Error: 27329.751953125
# Epoch 27/50, Loss: 592453824.0
# Network Valid Root Mean Squared Error: 29726.775390625
# Epoch 28/50, Loss: 149115520.0
# Network Valid Root Mean Squared Error: 27415.31640625
# Epoch 29/50, Loss: 29851725824.0
# Network Valid Root Mean Squared Error: 33762.12890625
# Epoch 30/50, Loss: 369733376.0
# Network Valid Root Mean Squared Error: 26084.9609375
# Epoch 31/50, Loss: 86814832.0
# Network Valid Root Mean Squared Error: 26933.294921875
# Epoch 32/50, Loss: 315747840.0
# Network Valid Root Mean Squared Error: 25326.4140625
# Epoch 33/50, Loss: 4189806848.0
# Network Valid Root Mean Squared Error: 32413.455078125
# Epoch 34/50, Loss: 168781152.0
# Network Valid Root Mean Squared Error: 26215.56640625
# Epoch 35/50, Loss: 123317080.0
# Network Valid Root Mean Squared Error: 28601.4140625
# Epoch 36/50, Loss: 152801904.0
# Network Valid Root Mean Squared Error: 28399.724609375
# Epoch 37/50, Loss: 383506336.0
# Network Valid Root Mean Squared Error: 25880.39453125
# Epoch 38/50, Loss: 567097984.0
# Network Valid Root Mean Squared Error: 24925.40234375
# Epoch 39/50, Loss: 117091128.0
# Network Valid Root Mean Squared Error: 24989.48046875
# Epoch 40/50, Loss: 60876324.0
# Network Valid Root Mean Squared Error: 25666.244140625
# Epoch 41/50, Loss: 159323072.0
# Network Valid Root Mean Squared Error: 25696.24609375
# Epoch 42/50, Loss: 827627776.0
# Network Valid Root Mean Squared Error: 24659.40625
# Epoch 43/50, Loss: 142432832.0
# Network Valid Root Mean Squared Error: 26837.27734375
# Epoch 44/50, Loss: 41825592.0
# Network Valid Root Mean Squared Error: 27459.541015625
# Epoch 45/50, Loss: 245747504.0
# Network Valid Root Mean Squared Error: 26120.0859375
# Epoch 46/50, Loss: 172292880.0
# Network Valid Root Mean Squared Error: 27736.08984375
# Epoch 47/50, Loss: 34117032.0
# Network Valid Root Mean Squared Error: 26496.568359375
# Epoch 48/50, Loss: 152728320.0
# Network Valid Root Mean Squared Error: 28519.029296875
# Epoch 49/50, Loss: 901816448.0
# Network Valid Root Mean Squared Error: 25540.626953125
# Epoch 50/50, Loss: 398187040.0
# Network Valid Root Mean Squared Error: 25934.138671875

# %%
input_dim = len(cat_nu_cols)
print(input_dim)
model = DeepResidualMLP(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_val
# Epoch 35/50, Loss: 460208544.0
# Network Valid Root Mean Squared Error: 29713.8828125
# Epoch 36/50, Loss: 153184624.0
# Network Valid Root Mean Squared Error: 34568.1015625
# Epoch 37/50, Loss: 364265568.0
# Network Valid Root Mean Squared Error: 29994.00390625
# Epoch 38/50, Loss: 267337280.0
# Network Valid Root Mean Squared Error: 30376.10546875
# Epoch 39/50, Loss: 623945088.0
# Network Valid Root Mean Squared Error: 33538.84375
# Epoch 40/50, Loss: 160860480.0
# Network Valid Root Mean Squared Error: 27829.486328125
# Epoch 41/50, Loss: 71997096.0
# Network Valid Root Mean Squared Error: 28847.486328125
# Epoch 42/50, Loss: 2139141376.0
# Network Valid Root Mean Squared Error: 39947.69140625
# Epoch 43/50, Loss: 486016256.0
# Network Valid Root Mean Squared Error: 30714.85546875
# Epoch 44/50, Loss: 109687224.0
# Network Valid Root Mean Squared Error: 27961.8828125
# Epoch 45/50, Loss: 405372416.0
# Network Valid Root Mean Squared Error: 28220.1328125
# Epoch 46/50, Loss: 205216208.0
# Network Valid Root Mean Squared Error: 28399.177734375
# Epoch 47/50, Loss: 1359720832.0
# Network Valid Root Mean Squared Error: 27051.521484375
# Epoch 48/50, Loss: 1157847680.0
# Network Valid Root Mean Squared Error: 27335.984375
# Epoch 49/50, Loss: 3273378304.0
# Network Valid Root Mean Squared Error: 27841.537109375
# Epoch 50/50, Loss: 364337952.0
# Network Valid Root Mean Squared Error: 30497.638671875

# %%
class DeepResidualMLP(nn.Module):
    def __init__(self, input_dim):
        super(DeepResidualMLP, self).__init__()
        self.layer1 = nn.Linear(input_dim, 256)
        self.layer2 = nn.Linear(256, 256)
        self.layer3 = nn.Linear(256, 256)
        self.layer4 = nn.Linear(256, 256)
        self.layer5 = nn.Linear(256, 256)
        self.output_layer = nn.Linear(256, 1)
        
        # ReLU activation
        self.relu = nn.ReLU()
        
        # Initializing weights with He initialization suitable for ReLU
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')

    def forward(self, x):
        # Input pass
        identity = x
        x = self.relu(self.layer1(x))
        
        # Residual block 1
        out = self.relu(self.layer2(x))
        out += x  # Adding input after the block
        
        # Residual block 2
        x = self.relu(self.layer3(out))
        x += out  # Adding input from the previous block
        
        # Residual block 3
        out = self.relu(self.layer4(x))
        out += x  # Adding input from the previous block
        
        # Residual block 4
        x = self.relu(self.layer5(out))
        x += out  # Adding input from the previous block

        # Output pass
        x = self.output_layer(x)
        return x

input_dim = len(cat_nu_cols)
print(input_dim)
model = DeepResidualMLP(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid)

# %%
input_dim = len(cat_nu_cols)
print(input_dim)
model = DeepResidualMLP(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid, 0.0001)
# Out:
# 49
# Epoch 1/50, Loss: 11512886272.0
# Network Valid Root Mean Squared Error: 58903.44140625
# Epoch 2/50, Loss: 4610254336.0
# Network Valid Root Mean Squared Error: 59210.67578125
# Epoch 3/50, Loss: 1613288704.0
# Network Valid Root Mean Squared Error: 41686.02734375
# Epoch 4/50, Loss: 1370993024.0
# Network Valid Root Mean Squared Error: 36505.40625
# Epoch 39/50, Loss: 383663296.0
# Network Valid Root Mean Squared Error: 33746.70703125
# Epoch 40/50, Loss: 316862720.0
# Network Valid Root Mean Squared Error: 27397.08203125
# Epoch 41/50, Loss: 226247264.0
# Network Valid Root Mean Squared Error: 28780.517578125
# Epoch 42/50, Loss: 1222909184.0
# Network Valid Root Mean Squared Error: 30092.646484375
# Epoch 43/50, Loss: 215932160.0
# Network Valid Root Mean Squared Error: 27711.619140625
# Epoch 44/50, Loss: 178803344.0
# Network Valid Root Mean Squared Error: 29363.01953125
# Epoch 45/50, Loss: 6836885504.0
# Network Valid Root Mean Squared Error: 30146.974609375
# Epoch 46/50, Loss: 573006336.0
# Network Valid Root Mean Squared Error: 38767.375
# Epoch 47/50, Loss: 147038160.0
# Network Valid Root Mean Squared Error: 27862.4453125
# Epoch 48/50, Loss: 159775904.0
# Network Valid Root Mean Squared Error: 28721.568359375
# Epoch 49/50, Loss: 103645592.0
# Network Valid Root Mean Squared Error: 27749.28515625
# Epoch 50/50, Loss: 109977312.0
# Network Valid Root Mean Squared Error: 27554.23046875

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Attention(nn.Module):
    def __init__(self, feature_dim):
        super(Attention, self).__init__()
        self.feature_dim = feature_dim
        
        self.key_layer = nn.Linear(feature_dim, feature_dim, bias=False)
        self.query_layer = nn.Linear(feature_dim, feature_dim, bias=False)

    def forward(self, x):
        query = self.query_layer(x).unsqueeze(1)  # Adding batch dimension
        key = self.key_layer(x).unsqueeze(-1)  # Adding an extra dimension for bmm
        
        # Compute attention scores and apply softmax
        scores = torch.bmm(query, key)  # Should work as both are 3D now
        weights = F.softmax(scores, dim=-1)
        
        # Apply weights to the original input features, using batch matrix multiplication
        attended = torch.bmm(weights, x.unsqueeze(1))  # x also needs to be 3D
        return attended.squeeze(1)  # Remove the extra dimension to match expected output shape





class DeepResidualMLPWithAttention(nn.Module):
    def __init__(self, input_dim):
        super(DeepResidualMLPWithAttention, self).__init__()
        self.layer1 = nn.Linear(input_dim, 256)
        self.layer2 = nn.Linear(256, 256)
        self.layer3 = nn.Linear(256, 256)
        self.layer4 = nn.Linear(256, 256)
        self.layer5 = nn.Linear(256, 256)
        self.attention = Attention(256)  # Attention layer after layer5
        self.output_layer = nn.Linear(256, 1)
        
        self.relu = nn.ReLU()
        
        # Initializing weights
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')

    def forward(self, x):
        identity = x
        x = self.relu(self.layer1(x))
        
        out = self.relu(self.layer2(x))
        out = out + x  # Use out-of-place operation

        x = self.relu(self.layer3(out))
        x = x + out  # Use out-of-place operation

        out = self.relu(self.layer4(x))
        out = out + x  # Use out-of-place operation

        x = self.relu(self.layer5(out))
        x = x + out  # Use out-of-place operation

        # Apply attention
        x = self.attention(x)
        x = self.output_layer(x)
        return x


input_dim = len(cat_nu_cols)
print(input_dim)
model = DeepResidualMLPWithAttention(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid)
# Out:
# 49
# Epoch 1/50, Loss: 1887785856.0
# Network Valid Root Mean Squared Error: 71526.5859375
# Epoch 2/50, Loss: 948286592.0
# Network Valid Root Mean Squared Error: 46926.1875
# Epoch 3/50, Loss: 32050630656.0
# Network Valid Root Mean Squared Error: 43911.2890625
# Epoch 4/50, Loss: 862836224.0
# Network Valid Root Mean Squared Error: 35629.88671875
# Epoch 5/50, Loss: 108751912.0
# Network Valid Root Mean Squared Error: 35285.72265625
# Epoch 6/50, Loss: 295243456.0
# Network Valid Root Mean Squared Error: 39063.46484375
# Epoch 7/50, Loss: 822696768.0
# Network Valid Root Mean Squared Error: 33228.5703125
# Epoch 8/50, Loss: 201165728.0
# Network Valid Root Mean Squared Error: 34531.9375
# Epoch 9/50, Loss: 183127696.0
# Network Valid Root Mean Squared Error: 31048.7734375
# Epoch 10/50, Loss: 1224703360.0
# Network Valid Root Mean Squared Error: 36200.25
# Epoch 11/50, Loss: 1976968576.0
# Network Valid Root Mean Squared Error: 31735.328125
# Epoch 12/50, Loss: 86958320.0
# Network Valid Root Mean Squared Error: 30018.66015625
# Epoch 13/50, Loss: 1821737856.0
# Network Valid Root Mean Squared Error: 32594.599609375
# Epoch 14/50, Loss: 273042336.0
# Network Valid Root Mean Squared Error: 31033.98046875
# Epoch 15/50, Loss: 612149760.0
# Network Valid Root Mean Squared Error: 28237.60546875
# Epoch 16/50, Loss: 324683584.0
# Network Valid Root Mean Squared Error: 33550.3828125
# Epoch 17/50, Loss: 1700450688.0
# Network Valid Root Mean Squared Error: 33955.1875
# Epoch 18/50, Loss: 370228672.0
# Network Valid Root Mean Squared Error: 33276.16015625
# Epoch 19/50, Loss: 164754128.0
# Network Valid Root Mean Squared Error: 27650.3984375
# Epoch 20/50, Loss: 105906624.0
# Network Valid Root Mean Squared Error: 35081.2265625
# Epoch 21/50, Loss: 4044793088.0
# Network Valid Root Mean Squared Error: 38874.15625
# Epoch 22/50, Loss: 107661968.0
# Network Valid Root Mean Squared Error: 27863.958984375
# Epoch 23/50, Loss: 263963360.0
# Network Valid Root Mean Squared Error: 27371.6796875
# Epoch 24/50, Loss: 80888096.0
# Network Valid Root Mean Squared Error: 27707.220703125
# Epoch 25/50, Loss: 72767152.0
# Network Valid Root Mean Squared Error: 26889.017578125
# Epoch 26/50, Loss: 1479459072.0
# Network Valid Root Mean Squared Error: 28913.55859375
# Epoch 27/50, Loss: 158296944.0
# Network Valid Root Mean Squared Error: 27169.111328125
# Epoch 28/50, Loss: 110773200.0
# Network Valid Root Mean Squared Error: 27710.515625
# Epoch 29/50, Loss: 27060170.0
# Network Valid Root Mean Squared Error: 25800.5625
# Epoch 30/50, Loss: 132967264.0
# Network Valid Root Mean Squared Error: 35122.1328125
# Epoch 31/50, Loss: 78154776.0
# Network Valid Root Mean Squared Error: 25752.705078125
# Epoch 32/50, Loss: 725168000.0
# Network Valid Root Mean Squared Error: 28502.0859375
# Epoch 33/50, Loss: 480964480.0
# Network Valid Root Mean Squared Error: 26457.0859375
# Epoch 34/50, Loss: 141928784.0
# Network Valid Root Mean Squared Error: 34360.8671875
# Epoch 35/50, Loss: 948170048.0
# Network Valid Root Mean Squared Error: 27631.01171875
# Epoch 36/50, Loss: 691243328.0
# Network Valid Root Mean Squared Error: 25762.427734375
# Epoch 37/50, Loss: 74797768.0
# Network Valid Root Mean Squared Error: 26252.716796875
# Epoch 38/50, Loss: 445450496.0
# Network Valid Root Mean Squared Error: 26466.78125
# Epoch 39/50, Loss: 124164632.0
# Network Valid Root Mean Squared Error: 26831.642578125
# Epoch 40/50, Loss: 113587800.0
# Network Valid Root Mean Squared Error: 28924.162109375
# Epoch 41/50, Loss: 532826400.0
# Network Valid Root Mean Squared Error: 26284.640625
# Epoch 42/50, Loss: 235329744.0
# Network Valid Root Mean Squared Error: 29425.19921875
# Epoch 43/50, Loss: 150150192.0
# Network Valid Root Mean Squared Error: 25956.080078125
# Epoch 44/50, Loss: 2464934656.0
# Network Valid Root Mean Squared Error: 26640.3203125
# Epoch 45/50, Loss: 90144912.0
# Network Valid Root Mean Squared Error: 25051.853515625
# Epoch 46/50, Loss: 79985968.0
# Network Valid Root Mean Squared Error: 26355.41796875
# Epoch 47/50, Loss: 63163496.0
# Network Valid Root Mean Squared Error: 26018.419921875
# Epoch 48/50, Loss: 326133344.0
# Network Valid Root Mean Squared Error: 25855.62109375
# Epoch 49/50, Loss: 135284864.0
# Network Valid Root Mean Squared Error: 26416.171875
# Epoch 50/50, Loss: 291508736.0
# Network Valid Root Mean Squared Error: 30110.984375

# %%
input_dim = len(cat_nu_cols)
print(input_dim)
model = DeepResidualMLPWithAttention(input_dim)
train_network(model, cat_nu_cols, X_train, y_train, X_valid, y_valid, 0.0001)
# Out:
# 49
# Epoch 1/50, Loss: 691887872.0
# Network Valid Root Mean Squared Error: 45991.30078125
# Epoch 2/50, Loss: 1080788992.0
# Network Valid Root Mean Squared Error: 43969.65625
# Epoch 3/50, Loss: 861395584.0
# Network Valid Root Mean Squared Error: 45759.296875
# Epoch 4/50, Loss: 3304551680.0
# Network Valid Root Mean Squared Error: 38121.75
# Epoch 5/50, Loss: 1366723968.0
# Network Valid Root Mean Squared Error: 43957.43359375
# Epoch 6/50, Loss: 640371520.0
# Network Valid Root Mean Squared Error: 37139.93359375
# Epoch 7/50, Loss: 785327872.0
# Network Valid Root Mean Squared Error: 34948.69140625
# Epoch 8/50, Loss: 7401106944.0
# Network Valid Root Mean Squared Error: 59052.0
# Epoch 9/50, Loss: 2596687360.0
# Network Valid Root Mean Squared Error: 35894.109375
# Epoch 10/50, Loss: 316112736.0
# Network Valid Root Mean Squared Error: 32746.7734375
# Epoch 11/50, Loss: 1351611648.0
# Network Valid Root Mean Squared Error: 33017.90234375
# Epoch 12/50, Loss: 617819456.0
# Network Valid Root Mean Squared Error: 34227.5078125
# Epoch 13/50, Loss: 281935648.0
# Network Valid Root Mean Squared Error: 32503.548828125
# Epoch 14/50, Loss: 179782688.0
# Network Valid Root Mean Squared Error: 33380.94140625
# Epoch 15/50, Loss: 275985792.0
# Network Valid Root Mean Squared Error: 32461.859375
# Epoch 16/50, Loss: 233932656.0
# Network Valid Root Mean Squared Error: 33402.5703125
# Epoch 17/50, Loss: 32499499008.0
# Network Valid Root Mean Squared Error: 33113.4375
# Epoch 18/50, Loss: 777700224.0
# Network Valid Root Mean Squared Error: 30895.26171875
# Epoch 19/50, Loss: 334856416.0
# Network Valid Root Mean Squared Error: 31591.708984375
# Epoch 20/50, Loss: 277549344.0
# Network Valid Root Mean Squared Error: 31218.486328125
# Epoch 21/50, Loss: 1880234112.0
# Network Valid Root Mean Squared Error: 30688.390625
# Epoch 22/50, Loss: 1674973312.0
# Network Valid Root Mean Squared Error: 32527.826171875
# Epoch 23/50, Loss: 1714675200.0
# Network Valid Root Mean Squared Error: 33926.59375
# Epoch 24/50, Loss: 317419328.0
# Network Valid Root Mean Squared Error: 29750.251953125
# Epoch 25/50, Loss: 245733840.0
# Network Valid Root Mean Squared Error: 36105.734375
# Epoch 26/50, Loss: 141622720.0
# Network Valid Root Mean Squared Error: 29249.1875
# Epoch 27/50, Loss: 164161232.0
# Network Valid Root Mean Squared Error: 38076.19921875
# Epoch 28/50, Loss: 328321152.0
# Network Valid Root Mean Squared Error: 30951.3203125
# Epoch 29/50, Loss: 131090880.0
# Network Valid Root Mean Squared Error: 28419.04296875
# Epoch 30/50, Loss: 280646432.0
# Network Valid Root Mean Squared Error: 30041.978515625
# Epoch 31/50, Loss: 3609779456.0
# Network Valid Root Mean Squared Error: 33366.59375
# Epoch 32/50, Loss: 216206992.0
# Network Valid Root Mean Squared Error: 29968.279296875
# Epoch 33/50, Loss: 256574784.0
# Network Valid Root Mean Squared Error: 28230.51953125
# Epoch 34/50, Loss: 1491842048.0
# Network Valid Root Mean Squared Error: 42683.71875
# Epoch 35/50, Loss: 553025152.0
# Network Valid Root Mean Squared Error: 30731.2734375
# Epoch 36/50, Loss: 121305864.0
# Network Valid Root Mean Squared Error: 29502.583984375
# Epoch 37/50, Loss: 137277232.0
# Network Valid Root Mean Squared Error: 28308.580078125
# Epoch 38/50, Loss: 3218181376.0
# Network Valid Root Mean Squared Error: 40029.42578125
# Epoch 39/50, Loss: 904694848.0
# Network Valid Root Mean Squared Error: 28923.728515625
# Epoch 40/50, Loss: 554897408.0
# Network Valid Root Mean Squared Error: 36170.65625
# Epoch 41/50, Loss: 211935968.0
# Network Valid Root Mean Squared Error: 28019.21875
# Epoch 42/50, Loss: 147558944.0
# Network Valid Root Mean Squared Error: 32013.80859375
# Epoch 43/50, Loss: 117711752.0
# Network Valid Root Mean Squared Error: 31584.244140625
# Epoch 44/50, Loss: 511719392.0
# Network Valid Root Mean Squared Error: 27491.935546875
# Epoch 45/50, Loss: 100211088.0
# Network Valid Root Mean Squared Error: 28403.474609375
# Epoch 46/50, Loss: 56704856.0
# Network Valid Root Mean Squared Error: 27288.255859375
# Epoch 47/50, Loss: 196197696.0
# Network Valid Root Mean Squared Error: 28310.263671875
# Epoch 48/50, Loss: 203317168.0
# Network Valid Root Mean Squared Error: 27090.208984375
# Epoch 49/50, Loss: 123237184.0
# Network Valid Root Mean Squared Error: 28325.33203125
# Epoch 50/50, Loss: 87482000.0
# Network Valid Root Mean Squared Error: 27192.1875

# %% [markdown]
# ## Prediction on test set

# %%
# 选择表现最好的模型进行最终训练和预测
best_model = DeeperMLPModel(input_dim)

print("使用全量数据训练最终模型...")
# 转换数据为tensor
X_train_full_tensor = torch.tensor(X_train_full[cat_nu_cols].values, dtype=torch.float32)
y_train_full_tensor = torch.tensor(y_train_full.values, dtype=torch.float32).view(-1, 1)
train_dataset = TensorDataset(X_train_full_tensor, y_train_full_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# 训练模型
criterion = nn.MSELoss()
optimizer = optim.Adam(best_model.parameters(), lr=0.001)

epochs = 50
for epoch in range(epochs):
    best_model.train()
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = best_model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')

print("生成测试集预测结果...")
best_model.eval()
X_test_tensor = torch.tensor(X_test[cat_nu_cols].values, dtype=torch.float32)
with torch.no_grad():
    test_predictions = best_model(X_test_tensor).numpy()

# 创建预测结果DataFrame
predictions_df = pd.DataFrame({
    'Id': range(len(test_predictions)),
    'Predicted': test_predictions.flatten()
})

# 保存预测结果
predictions_df.to_csv('data/predictions.csv', index=False)
print("预测结果已保存到 data/predictions.csv")
# Out:
# 使用全量数据训练最终模型...
# Epoch 1/50, Loss: 601384704.0
# Epoch 2/50, Loss: 344548352.0
# Epoch 3/50, Loss: 228334368.0
# Epoch 4/50, Loss: 363200256.0
# Epoch 5/50, Loss: 80958416.0
# Epoch 6/50, Loss: 84301576.0
# Epoch 7/50, Loss: 130191664.0
# Epoch 8/50, Loss: 75877600.0
# Epoch 9/50, Loss: 149877904.0
# Epoch 10/50, Loss: 21615413248.0
# Epoch 11/50, Loss: 247241296.0
# Epoch 12/50, Loss: 24582738.0
# Epoch 13/50, Loss: 117100784.0
# Epoch 14/50, Loss: 1098592384.0
# Epoch 15/50, Loss: 281298624.0
# Epoch 16/50, Loss: 109165384.0
# Epoch 17/50, Loss: 76281576.0
# Epoch 18/50, Loss: 153431168.0
# Epoch 19/50, Loss: 257027136.0
# Epoch 20/50, Loss: 112057608.0
# Epoch 21/50, Loss: 499631744.0
# Epoch 22/50, Loss: 120539304.0
# Epoch 23/50, Loss: 456576672.0
# Epoch 24/50, Loss: 703028352.0
# Epoch 25/50, Loss: 26557404.0
# Epoch 26/50, Loss: 173423232.0
# Epoch 27/50, Loss: 1163090304.0
# Epoch 28/50, Loss: 152474288.0
# Epoch 29/50, Loss: 327823680.0
# Epoch 30/50, Loss: 12463853.0
# Epoch 31/50, Loss: 217957232.0
# Epoch 32/50, Loss: 121490160.0
# Epoch 33/50, Loss: 39935716.0
# Epoch 34/50, Loss: 257247920.0
# Epoch 35/50, Loss: 66070852.0
# Epoch 36/50, Loss: 1010823168.0
# Epoch 37/50, Loss: 22981520.0
# Epoch 38/50, Loss: 25372570.0
# Epoch 39/50, Loss: 20777086.0
# Epoch 40/50, Loss: 2659428096.0
# Epoch 41/50, Loss: 29396916.0
# Epoch 42/50, Loss: 245404880.0
# Epoch 43/50, Loss: 158274144.0
# Epoch 44/50, Loss: 122282536.0
# Epoch 45/50, Loss: 48840592.0
# Epoch 46/50, Loss: 328924992.0
# Epoch 47/50, Loss: 63125908.0
# Epoch 48/50, Loss: 701413696.0
# Epoch 49/50, Loss: 107856288.0
# Epoch 50/50, Loss: 2907736320.0
# 生成测试集预测结果...
# 预测结果已保存到 data/predictions.csv
