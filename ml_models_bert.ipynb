# %%
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import json
import math

# 读取处理后的数据集
X_train = pd.read_csv('data/processed/X_train.csv')
y_train = pd.read_csv('data/processed/y_train.csv')
X_valid = pd.read_csv('data/processed/X_valid.csv')
y_valid = pd.read_csv('data/processed/y_valid.csv') 
X_train_full = pd.read_csv('data/processed/X_train_full.csv') 
y_train_full = pd.read_csv('data/processed/y_train_full.csv') 
X_test = pd.read_csv('data/processed/X_test.csv')

print('数据集读取完成')
print(f'训练集大小: {X_train.shape}')
print(f'验证集大小: {X_valid.shape}')
print(f'全量训练集大小: {X_train_full.shape}')
print(f'测试集大小: {X_test.shape}')
# Out:
# 数据集读取完成
# 训练集大小: (20000, 74)
# 验证集大小: (5000, 74)
# 全量训练集大小: (25000, 74)
# 测试集大小: (10000, 74)

# %%
# 直接定义列名配置
del_cols = ['listing_id', 'original_reg_date', 'opc_scheme', 'lifespan', 'eco_category', 'indicative_price']
text_cols = ['title', 'description', 'features', 'accessories']
date_cols = ['reg_date']
numeric_cols = ['manufactured', 'curb_weight', 'power', 'engine_cap', 'depreciation', 'coe', 'road_tax', 
                'dereg_value', 'mileage', 'omv', 'arf', 'year', 'month',
                'text_brand_popularity_score', 'text_model_value_score', 'text_condition_score',
                'text_feature_rarity_score', 'text_performance_score', 'text_sentiment_score']
log_cols = ['manufactured', 'curb_weight', 'power_log', 'engine_cap_log', 'depreciation_log', 'coe', 
            'road_tax_log', 'dereg_value_log', 'mileage_log', 'omv_log', 'arf_log', 'year', 'month']
root_cols = ['manufactured', 'curb_weight', 'power_root', 'engine_cap_root', 'depreciation_root', 'coe', 
             'road_tax_root', 'dereg_value_root', 'mileage_root', 'omv_root', 'arf_root', 'year', 'month']
categorical_cols = ['make', 'model', 'type_of_vehicle', 'category', 'transmission', 'fuel_type', 'no_of_owners']

# 更新变换列，添加GPT特征
cat_nu_cols = [
    "manufactured", "curb_weight", "power", "engine_cap", "no_of_owners", "depreciation", 
    "coe", "road_tax", "dereg_value", "mileage", "omv", "arf", "make_target_encoded",
    "text_brand_popularity_score", "text_model_value_score", "text_condition_score",
    "text_feature_rarity_score", "text_performance_score", "text_sentiment_score",
    "-", "almost new car", "coe car", "consignment car", "direct owner sale", 
    "electric cars", "hybrid cars", "imported used vehicle", "low mileage car", 
    "opc car", "parf car", "premium ad car", "rare & exotic", "sgcarmart warranty cars", 
    "sta evaluated car", "vintage cars", "type_of_vehicle_bus/mini bus", 
    "type_of_vehicle_hatchback", "type_of_vehicle_luxury sedan", 
    "type_of_vehicle_mid-sized sedan", "type_of_vehicle_mpv", "type_of_vehicle_others", 
    "type_of_vehicle_sports car", "type_of_vehicle_stationwagon", "type_of_vehicle_suv", 
    "type_of_vehicle_truck", "type_of_vehicle_van", "fuel_type_diesel", 
    "fuel_type_diesel-electric", "fuel_type_electric", "fuel_type_petrol", 
    "fuel_type_petrol-electric", "fuel_type_nan", "transmission_manual", "year", "month"
]

cat_log_cols = [
    "manufactured", "curb_weight", "power_log", "engine_cap_log", "depreciation_log", 
    "coe", "road_tax_log", "dereg_value_log", "mileage_log", "omv_log", "arf_log", 
    "make_target_encoded", "text_brand_popularity_score", "text_model_value_score", 
    "text_condition_score", "text_feature_rarity_score", "text_performance_score", 
    "text_sentiment_score", "-", "almost new car", "coe car", "consignment car", 
    "direct owner sale", "electric cars", "hybrid cars", "imported used vehicle", 
    "low mileage car", "opc car", "parf car", "premium ad car", "rare & exotic", 
    "sgcarmart warranty cars", "sta evaluated car", "vintage cars", 
    "type_of_vehicle_bus/mini bus", "type_of_vehicle_hatchback", 
    "type_of_vehicle_luxury sedan", "type_of_vehicle_mid-sized sedan", 
    "type_of_vehicle_mpv", "type_of_vehicle_others", "type_of_vehicle_sports car", 
    "type_of_vehicle_stationwagon", "type_of_vehicle_suv", "type_of_vehicle_truck", 
    "type_of_vehicle_van", "fuel_type_diesel", "fuel_type_diesel-electric", 
    "fuel_type_electric", "fuel_type_petrol", "fuel_type_petrol-electric", 
    "fuel_type_nan", "transmission_manual", "year", "month"
]

cat_root_cols = [
    "manufactured", "curb_weight", "power_root", "engine_cap_root", "depreciation_root", 
    "coe", "road_tax_root", "dereg_value_root", "mileage_root", "omv_root", "arf_root", 
    "make_target_encoded", "text_brand_popularity_score", "text_model_value_score", 
    "text_condition_score", "text_feature_rarity_score", "text_performance_score", 
    "text_sentiment_score", "-", "almost new car", "coe car", "consignment car", 
    "direct owner sale", "electric cars", "hybrid cars", "imported used vehicle", 
    "low mileage car", "opc car", "parf car", "premium ad car", "rare & exotic", 
    "sgcarmart warranty cars", "sta evaluated car", "vintage cars", 
    "type_of_vehicle_bus/mini bus", "type_of_vehicle_hatchback", 
    "type_of_vehicle_luxury sedan", "type_of_vehicle_mid-sized sedan", 
    "type_of_vehicle_mpv", "type_of_vehicle_others", "type_of_vehicle_sports car", 
    "type_of_vehicle_stationwagon", "type_of_vehicle_suv", "type_of_vehicle_truck", 
    "type_of_vehicle_van", "fuel_type_diesel", "fuel_type_diesel-electric", 
    "fuel_type_electric", "fuel_type_petrol", "fuel_type_petrol-electric", 
    "fuel_type_nan", "transmission_manual", "year", "month"
]

# 丢弃log和root变换的结果
X_train = X_train[cat_nu_cols]
X_valid = X_valid[cat_nu_cols]
X_test = X_test[cat_nu_cols]
X_train_full = X_train_full[cat_nu_cols]

print(f'训练集: {X_train.shape}')
print(f'全量集: {X_train_full.shape}')
print(f'测试集: {X_test.shape}')
# Out:
# 训练集: (20000, 55)
# 全量集: (25000, 55)
# 测试集: (10000, 55)

# %% [markdown]
# ## Additional Feature Engineering

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectFromModel
from xgboost import XGBRegressor

def create_new_features(df):
    """创建更有针对性的特征"""
    
    # 1. 核心价值特征 - 更关注直接影响价格的因素
    df['total_base_cost'] = df['omv'] + df['arf']  # 基础成本(不含COE)
    df['coe_ratio'] = df['coe'] / df['total_base_cost'].clip(lower=1)  # COE占比
    df['dereg_ratio'] = df['dereg_value'] / df['total_base_cost'].clip(lower=1)  # 折价率
    
    # 2. 车况评估 - 重点关注车辆状态
    df['age'] = 2024 - df['manufactured']
    df['km_per_year'] = df['mileage'] / df['age'].clip(lower=1)
    df['wear_tear_index'] = (
        df['km_per_year'] / 20000 +  # 标准年行驶里程
        df['age'] / 10 +             # 车龄影响
        df['no_of_owners'] / 2       # 车主数影响
    )
    
    # 3. 性能价值比 - 更注重实用性指标
    df['power_price_ratio'] = df['power'] / df['total_base_cost'].clip(lower=1) * 1000
    df['weight_efficiency'] = df['power'] / df['curb_weight'].clip(lower=1)
    
    return df

def select_features(X_train, y_train, X_valid, feature_names, threshold=0.001):
    """特征选择"""
    # 1. 基于XGBoost的特征重要性
    xgb_selector = SelectFromModel(
        XGBRegressor(
            n_estimators=500,
            learning_rate=0.1,
            max_depth=5,
            random_state=42
        ),
        threshold=threshold
    )
    
    # 2. 保留重要特征
    X_train_selected = xgb_selector.fit_transform(X_train, y_train)
    selected_features_mask = xgb_selector.get_support()
    selected_features = [f for f, selected in zip(feature_names, selected_features_mask) if selected]
    
    # 3. 转换验证集
    X_valid_selected = xgb_selector.transform(X_valid)
    
    return X_train_selected, X_valid_selected, selected_features

# 主流程
def feature_engineering_pipeline(X_train, X_valid, y_train, y_valid):
    """特征工程主流程"""
    print("开始特征工程...")
    
    # 1. 创建新特征
    print("创建新特征...")
    X_train_new = create_new_features(X_train.copy())
    X_valid_new = create_new_features(X_valid.copy())
    
    # 2. 特征选择
    print("进行特征选择...")
    feature_names = list(X_train_new.columns)
    X_train_selected, X_valid_selected, selected_features = select_features(
        X_train_new, y_train, X_valid_new, feature_names
    )
    
    print(f"原始特征数: {len(feature_names)}")
    print(f"选择后特征数: {len(selected_features)}")
    print("\n重要特征:")
    print(selected_features)
    
    return X_train_selected, X_valid_selected, selected_features


# 使用示例
# X_train_final, X_valid_final, selected_features = feature_engineering_pipeline(
#     X_train, X_valid, y_train, y_valid
# )

# 不进行特征选择
X_train_final = create_new_features(X_train.copy())
X_valid_final = create_new_features(X_valid.copy())

# 评估新特征的效果
model = XGBRegressor(
    # 基本参数
    n_estimators=1000,        # 树的数量
    max_depth=6,              # 树的最大深度，避免过拟合
    learning_rate=0.01,       # 较小的学习率，提高模型稳定性
    
    # 防止过拟合的参数
    min_child_weight=5,       # 控制过拟合
    gamma=0.1,               # 节点分裂所需的最小损失函数下降值
    subsample=0.8,           # 随机采样训练样本的比例
    colsample_bytree=0.8,    # 随机采样特征的比例
    
    # 正则化参数
    reg_alpha=0.1,           # L1正则化
    reg_lambda=1,            # L2正则化
    
    # 其他参数
    objective='reg:squarederror',  # 回归任务
    random_state=42,
    n_jobs=-1,               # 使用所有CPU核心
    verbosity=0
)

model.fit(X_train_final, y_train)
y_pred = model.predict(X_valid_final)
rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
r2 = r2_score(y_valid, y_pred)

print(f"\n模型性能:")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.4f}")
# Out:
# 模型性能:
# RMSE: 22985.43
# R2: 0.9744

# %% [markdown]
# ## Concat BERT Vectors

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from umap.umap_ import UMAP  # 正确的导入方式

# 加载BERT向量
bert_train_vectors = np.load('data/processed/train_vectors.npy')
bert_valid_vectors = np.load('data/processed/valid_vectors.npy')
bert_train_full_vectors = np.load('data/processed/train_full_vectors.npy')
bert_test_vectors = np.load('data/processed/test_vectors.npy')

# BERT降维
scaler = StandardScaler()

# UMAP参数设置
umap = UMAP(
    n_components=8,
    n_neighbors=20,
    min_dist=0.1,
    metric='cosine',
    random_state=42
)

# umap = UMAP(
#     n_components=16,
#     n_neighbors=30,
#     min_dist=0.3,
#     metric='cosine',
#     random_state=42
# )

# umap = UMAP(
#     n_components=24,
#     n_neighbors=50,
#     min_dist=0.5,
#     metric='cosine',
#     random_state=42
# )

# 对BERT向量进行UMAP降维
bert_train_scaled = scaler.fit_transform(bert_train_vectors)
bert_train_umap = umap.fit_transform(bert_train_scaled)

# 对验证集和测试集应用相同的转换
bert_valid_scaled = scaler.transform(bert_valid_vectors)
bert_valid_umap = umap.transform(bert_valid_scaled)

bert_test_scaled = scaler.transform(bert_test_vectors)
bert_test_umap = umap.transform(bert_test_scaled)

# 对完整训练集进行转换
bert_train_full_scaled = scaler.transform(bert_train_full_vectors)
bert_train_full_umap = umap.transform(bert_train_full_scaled)

# 拼接特征
X_train_combined = np.hstack((X_train[cat_nu_cols].values, bert_train_umap))
X_valid_combined = np.hstack((X_valid[cat_nu_cols].values, bert_valid_umap))
X_test_combined = np.hstack((X_test[cat_nu_cols].values, bert_test_umap))
X_train_full_combined = np.hstack((X_train_full[cat_nu_cols].values, bert_train_full_umap))

# X_train_combined = np.hstack((X_train_final, bert_train_umap))
# X_valid_combined = np.hstack((X_valid_final, bert_valid_umap))
# X_test_combined = np.hstack((X_test_final, bert_test_umap))

# 打印维度信息
print("特征维度:")
print(f"原始特征: {X_train[cat_nu_cols].shape[1]}")
print(f"UMAP特征: {bert_train_umap.shape[1]}")
print(f"组合特征: {X_train_combined.shape[1]}")
# Out:
# c:\Users\10021\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 特征维度:
# 原始特征: 55
# UMAP特征: 8
# 组合特征: 63

# %%
print(X_train_full_combined.shape)
print(X_test_combined.shape)
# Out:
# (25000, 63)
# (10000, 63)

# %% [markdown]
# ## Baseline

# %%
# 使用数值特征 + 分类特征
for li in [cat_nu_cols, cat_log_cols, cat_root_cols]:
    # Assuming 'data' is your DataFrame and 'target' is the name of your target variable
    X = X_train[li]  # Features
    y = y_train       # Target variable

    # Creating the linear regression model
    model = LinearRegression()

    # Fitting the model
    model.fit(X, y)

    # Making predictions
    y_valid_pred = model.predict(X_valid[li])

    # Calculating the performance metrics
    mse = mean_squared_error(y_valid_pred, y_valid)
    r2 = r2_score(y_valid_pred, y_valid)
    # Calculating the RMSE
    rmse = math.sqrt(mse)

    # Printing the MSE, RMSE, and R² Score
    print(f'Mean Squared Error: {mse}')
    print(f'Root Mean Squared Error: {rmse}')
    print(f'R² Score: {r2}')
# Out:
# Mean Squared Error: 1992363754.8560255
# Root Mean Squared Error: 44635.902084040215
# R² Score: 0.9000067197216133
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 # 使用数值特征 + 分类特征
#       2 for li in [cat_nu_cols, cat_log_cols, cat_root_cols]:
#       3     # Assuming 'data' is your DataFrame and 'target' is the name of your target variable
# ----> 4     X = X_train[li]  # Features
#       5     y = y_train       # Target variable
#       7     # Creating the linear regression model
#
# File c:\Users\10021\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\10021\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File c:\Users\10021\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6179, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['power_log', 'engine_cap_log', 'depreciation_log', 'road_tax_log', 'dereg_value_log', 'mileage_log', 'omv_log', 'arf_log'] not in index"

# %%
# Assuming 'data' is your DataFrame and 'target' is the name of your target variable
X = X_train_combined 
y = y_train

# Creating the linear regression model
model = LinearRegression()

# Fitting the model
model.fit(X, y)

# Making predictions
y_valid_pred = model.predict(X_valid_combined)

# Calculating the performance metrics
mse = mean_squared_error(y_valid_pred, y_valid)
r2 = r2_score(y_valid_pred, y_valid)
# Calculating the RMSE
rmse = math.sqrt(mse)

# Printing the MSE, RMSE, and R² Score
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
print(f'R² Score: {r2}')
# Out:
# Mean Squared Error: 1983291413.9657602
# Root Mean Squared Error: 44534.160079266796
# R² Score: 0.900433064359746

# %% [markdown]
# ## Other ML Regression Models

# %%
from xgboost import XGBRegressor

# # 创建XGBoost模型
model = XGBRegressor(
    # 基本参数
    n_estimators=1000,        # 树的数量
    max_depth=6,              # 树的最大深度，避免过拟合
    learning_rate=0.01,       # 较小的学习率，提高模型稳定性
    
    # 防止过拟合的参数
    min_child_weight=5,       # 控制过拟合
    gamma=0.1,               # 节点分裂所需的最小损失函数下降值
    subsample=0.8,           # 随机采样训练样本的比例
    colsample_bytree=0.8,    # 随机采样特征的比例
    
    # 正则化参数
    reg_alpha=0.1,           # L1正则化
    reg_lambda=1,            # L2正则化
    
    # 其他参数
    objective='reg:squarederror',  # 回归任务
    random_state=42,
    n_jobs=-1,               # 使用所有CPU核心
    verbosity=0
)


# Assuming 'data' is your DataFrame and 'target' is the name of your target variable
X = X_train[cat_nu_cols]  # Features
y = y_train       # Target variable

print(X.shape)

# 添加早停以防止过拟合
eval_set = [(X_valid[cat_nu_cols], y_valid)]

model.fit(
    X, 
    y,
    eval_set=eval_set
)

# Making predictions
y_valid_pred = model.predict(X_valid[cat_nu_cols])

# Calculating the performance metrics
mse = mean_squared_error(y_valid_pred, y_valid)
r2 = r2_score(y_valid_pred, y_valid)
# Calculating the RMSE
rmse = math.sqrt(mse)

# Printing the MSE, RMSE, and R² Score
# print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# print(f'R² Score: {r2}')
# Out:
# (20000, 55)
# [0]	validation_0-rmse:142305.28978
# [1]	validation_0-rmse:141073.61113
# [2]	validation_0-rmse:139832.50912
# [3]	validation_0-rmse:138602.55269
# [4]	validation_0-rmse:137381.99361
# [5]	validation_0-rmse:136161.27380
# [6]	validation_0-rmse:134973.88400
# [7]	validation_0-rmse:133810.38658
# [8]	validation_0-rmse:132629.46748
# [9]	validation_0-rmse:131502.00132
# [10]	validation_0-rmse:130374.25110
# [11]	validation_0-rmse:129232.83034
# [12]	validation_0-rmse:128162.64400
# [13]	validation_0-rmse:127060.01492
# [14]	validation_0-rmse:125971.64119
# [15]	validation_0-rmse:124912.96681
# [16]	validation_0-rmse:123839.65387
# [17]	validation_0-rmse:122762.95582
# [18]	validation_0-rmse:121715.07801
# [19]	validation_0-rmse:120676.25212
# [20]	validation_0-rmse:119657.95404
# [21]	validation_0-rmse:118641.09480
# [22]	validation_0-rmse:117622.64315
# [23]	validation_0-rmse:116624.51492
# [24]	validation_0-rmse:115640.06397
# [25]	validation_0-rmse:114618.93057
# [26]	validation_0-rmse:113659.17388
# [27]	validation_0-rmse:112721.27766
# [28]	validation_0-rmse:111781.19852
# [29]	validation_0-rmse:110825.75361
# [30]	validation_0-rmse:109909.82905
# [31]	validation_0-rmse:108966.72735
# [32]	validation_0-rmse:108035.87789
# [33]	validation_0-rmse:107136.96382
# [34]	validation_0-rmse:106246.34840
# [35]	validation_0-rmse:105381.49696
# [36]	validation_0-rmse:104501.77925
# [37]	validation_0-rmse:103629.59224
# [38]	validation_0-rmse:102750.57759
# [39]	validation_0-rmse:101891.03843
# [40]	validation_0-rmse:101061.58983
# [41]	validation_0-rmse:100239.34218
# [42]	validation_0-rmse:99404.25353
# [43]	validation_0-rmse:98608.32131
# [44]	validation_0-rmse:97788.46676
# [45]	validation_0-rmse:97018.49473
# [46]	validation_0-rmse:96237.55221
# [47]	validation_0-rmse:95474.04556
# [48]	validation_0-rmse:94667.06546
# [49]	validation_0-rmse:93886.34253
# [50]	validation_0-rmse:93101.13708
# [51]	validation_0-rmse:92302.30000
# [52]	validation_0-rmse:91535.89888
# [53]	validation_0-rmse:90806.54183
# [54]	validation_0-rmse:90059.40056
# [55]	validation_0-rmse:89319.46246
# [56]	validation_0-rmse:88581.78796
# [57]	validation_0-rmse:87857.44288
# [58]	validation_0-rmse:87189.64756
# [59]	validation_0-rmse:86481.43082
# [60]	validation_0-rmse:85789.59766
# [61]	validation_0-rmse:85099.90811
# [62]	validation_0-rmse:84447.94916
# [63]	validation_0-rmse:83765.02666
# [64]	validation_0-rmse:83136.92559
# [65]	validation_0-rmse:82478.12072
# [66]	validation_0-rmse:81860.63995
# [67]	validation_0-rmse:81213.23469
# [68]	validation_0-rmse:80586.84902
# [69]	validation_0-rmse:79969.34811
# [70]	validation_0-rmse:79334.70927
# [71]	validation_0-rmse:78729.34857
# [453]	validation_0-rmse:23981.32148
# [454]	validation_0-rmse:23972.45489
# [455]	validation_0-rmse:23970.54080
# [456]	validation_0-rmse:23960.91000
# [457]	validation_0-rmse:23950.48778
# [458]	validation_0-rmse:23941.36392
# [459]	validation_0-rmse:23935.73700
# [460]	validation_0-rmse:23931.11896
# [461]	validation_0-rmse:23927.33567
# [462]	validation_0-rmse:23924.16579
# [463]	validation_0-rmse:23916.59320
# [464]	validation_0-rmse:23905.20754
# [465]	validation_0-rmse:23892.55629
# [466]	validation_0-rmse:23894.86611
# [467]	validation_0-rmse:23891.39923
# [468]	validation_0-rmse:23888.37226
# [469]	validation_0-rmse:23885.07194
# [470]	validation_0-rmse:23872.05880
# [471]	validation_0-rmse:23870.94724
# [472]	validation_0-rmse:23867.48107
# [473]	validation_0-rmse:23866.24092
# [474]	validation_0-rmse:23868.37710
# [475]	validation_0-rmse:23866.53723
# [476]	validation_0-rmse:23869.00218
# [477]	validation_0-rmse:23870.36695
# [478]	validation_0-rmse:23868.63568
# [479]	validation_0-rmse:23865.87820
# [480]	validation_0-rmse:23864.92613
# [481]	validation_0-rmse:23858.99145
# [482]	validation_0-rmse:23859.02032
# [483]	validation_0-rmse:23850.60889
# [484]	validation_0-rmse:23847.73709
# [485]	validation_0-rmse:23848.70771
# [486]	validation_0-rmse:23845.83781
# [487]	validation_0-rmse:23839.55458
# [488]	validation_0-rmse:23831.15804
# [489]	validation_0-rmse:23829.96364
# [490]	validation_0-rmse:23816.67901
# [491]	validation_0-rmse:23819.78444
# [492]	validation_0-rmse:23801.88638
# [493]	validation_0-rmse:23796.23050
# [494]	validation_0-rmse:23792.56706
# [495]	validation_0-rmse:23790.45982
# [496]	validation_0-rmse:23791.02502
# [497]	validation_0-rmse:23791.86428
# [498]	validation_0-rmse:23791.74126
# [499]	validation_0-rmse:23796.33350
# [500]	validation_0-rmse:23795.20154
# [501]	validation_0-rmse:23793.66527
# [502]	validation_0-rmse:23790.53428
# [503]	validation_0-rmse:23784.18609
# [504]	validation_0-rmse:23775.80644
# [505]	validation_0-rmse:23775.68445
# [506]	validation_0-rmse:23765.95625
# [507]	validation_0-rmse:23755.95046
# [508]	validation_0-rmse:23749.98497
# [509]	validation_0-rmse:23743.79992
# [510]	validation_0-rmse:23736.63041
# [511]	validation_0-rmse:23737.47630
# [512]	validation_0-rmse:23743.62199
# [513]	validation_0-rmse:23743.48206
# [514]	validation_0-rmse:23744.71731
# [515]	validation_0-rmse:23738.92974
# [516]	validation_0-rmse:23736.38411
# [517]	validation_0-rmse:23741.09923
# [518]	validation_0-rmse:23733.59464
# [519]	validation_0-rmse:23735.69155
# [520]	validation_0-rmse:23728.41291
# [521]	validation_0-rmse:23728.93834
# [522]	validation_0-rmse:23730.26369
# [523]	validation_0-rmse:23730.51032
# [524]	validation_0-rmse:23725.84854
# [525]	validation_0-rmse:23721.66783
# [526]	validation_0-rmse:23717.98302
# [527]	validation_0-rmse:23715.97491
# [528]	validation_0-rmse:23708.87963
# [605]	validation_0-rmse:23523.57299
# [606]	validation_0-rmse:23519.94039
# [607]	validation_0-rmse:23517.00748
# [608]	validation_0-rmse:23519.77157
# [609]	validation_0-rmse:23518.33150
# [610]	validation_0-rmse:23517.82059
# [611]	validation_0-rmse:23512.08105
# [612]	validation_0-rmse:23516.51902
# [613]	validation_0-rmse:23509.33545
# [614]	validation_0-rmse:23498.29360
# [615]	validation_0-rmse:23500.14030
# [616]	validation_0-rmse:23495.49355
# [617]	validation_0-rmse:23489.03742
# [618]	validation_0-rmse:23492.76918
# [619]	validation_0-rmse:23493.47728
# [620]	validation_0-rmse:23490.46063
# [621]	validation_0-rmse:23492.60268
# [622]	validation_0-rmse:23490.40928
# [623]	validation_0-rmse:23485.87338
# [624]	validation_0-rmse:23482.30093
# [625]	validation_0-rmse:23483.14456
# [626]	validation_0-rmse:23481.86512
# [627]	validation_0-rmse:23484.85410
# [628]	validation_0-rmse:23484.32628
# [629]	validation_0-rmse:23481.03439
# [630]	validation_0-rmse:23478.73840
# [631]	validation_0-rmse:23476.48909
# [632]	validation_0-rmse:23472.83202
# [633]	validation_0-rmse:23473.08186
# [634]	validation_0-rmse:23475.14429
# [635]	validation_0-rmse:23474.71876
# [636]	validation_0-rmse:23474.16639
# [637]	validation_0-rmse:23472.66323
# [638]	validation_0-rmse:23468.73585
# [639]	validation_0-rmse:23466.23647
# [640]	validation_0-rmse:23458.63250
# [641]	validation_0-rmse:23457.41463
# [642]	validation_0-rmse:23455.02563
# [643]	validation_0-rmse:23449.84459
# [644]	validation_0-rmse:23445.10437
# [645]	validation_0-rmse:23439.70627
# [646]	validation_0-rmse:23443.53705
# [647]	validation_0-rmse:23442.21363
# [648]	validation_0-rmse:23438.79272
# [649]	validation_0-rmse:23435.03326
# [650]	validation_0-rmse:23435.11853
# [651]	validation_0-rmse:23442.36527
# [652]	validation_0-rmse:23445.05701
# [653]	validation_0-rmse:23439.30161
# [654]	validation_0-rmse:23435.32318
# [655]	validation_0-rmse:23431.20180
# [656]	validation_0-rmse:23431.22489
# [657]	validation_0-rmse:23427.13997
# [658]	validation_0-rmse:23424.86903
# [659]	validation_0-rmse:23423.24985
# [660]	validation_0-rmse:23424.59137
# [661]	validation_0-rmse:23429.15276
# [662]	validation_0-rmse:23425.80933
# [663]	validation_0-rmse:23422.54892
# [664]	validation_0-rmse:23421.97018
# [665]	validation_0-rmse:23423.44045
# [666]	validation_0-rmse:23427.94636
# [667]	validation_0-rmse:23424.59116
# [668]	validation_0-rmse:23422.24378
# [669]	validation_0-rmse:23417.29838
# [670]	validation_0-rmse:23418.97230
# [671]	validation_0-rmse:23425.25368
# [672]	validation_0-rmse:23422.14839
# [673]	validation_0-rmse:23426.79572
# [674]	validation_0-rmse:23427.76226
# [675]	validation_0-rmse:23424.36671
# [676]	validation_0-rmse:23417.33089
# [677]	validation_0-rmse:23421.25043
# [678]	validation_0-rmse:23418.47549
# [679]	validation_0-rmse:23416.26911
# [680]	validation_0-rmse:23420.66401
# [681]	validation_0-rmse:23418.61357
# [682]	validation_0-rmse:23413.67134
# [683]	validation_0-rmse:23408.58374
# [684]	validation_0-rmse:23410.85069
# [685]	validation_0-rmse:23407.03155
# [686]	validation_0-rmse:23410.04804
# [687]	validation_0-rmse:23411.78807
# [688]	validation_0-rmse:23411.50313
# [689]	validation_0-rmse:23407.85393
# [690]	validation_0-rmse:23407.61164
# [691]	validation_0-rmse:23404.58992
# [692]	validation_0-rmse:23400.58650
# [693]	validation_0-rmse:23398.63026
# [694]	validation_0-rmse:23393.40773
# [695]	validation_0-rmse:23392.92653
# [696]	validation_0-rmse:23390.00813
# [697]	validation_0-rmse:23388.95055
# [698]	validation_0-rmse:23390.06795
# [699]	validation_0-rmse:23390.93032
# [700]	validation_0-rmse:23390.79864
# [701]	validation_0-rmse:23392.47040
# [702]	validation_0-rmse:23394.36527
# [703]	validation_0-rmse:23391.70671
# [704]	validation_0-rmse:23392.46485
# [705]	validation_0-rmse:23392.26016
# [706]	validation_0-rmse:23391.36069
# [707]	validation_0-rmse:23387.80266
# [708]	validation_0-rmse:23386.20307
# [709]	validation_0-rmse:23381.54550
# [710]	validation_0-rmse:23379.14452
# [711]	validation_0-rmse:23382.15434
# [712]	validation_0-rmse:23379.66900
# [713]	validation_0-rmse:23383.91890
# [714]	validation_0-rmse:23382.82712
# [715]	validation_0-rmse:23378.94643
# [716]	validation_0-rmse:23388.69872
# [717]	validation_0-rmse:23383.72263
# [718]	validation_0-rmse:23384.70134
# [719]	validation_0-rmse:23386.14723
# [720]	validation_0-rmse:23387.07179
# [721]	validation_0-rmse:23390.66522
# [722]	validation_0-rmse:23388.25746
# [723]	validation_0-rmse:23382.21891
# [724]	validation_0-rmse:23381.61595
# [725]	validation_0-rmse:23378.04528
# [726]	validation_0-rmse:23380.44636
# [727]	validation_0-rmse:23379.80980
# [728]	validation_0-rmse:23378.12049
# [729]	validation_0-rmse:23375.34933
# [730]	validation_0-rmse:23370.42627
# [731]	validation_0-rmse:23366.26386
# [732]	validation_0-rmse:23362.76548
# [733]	validation_0-rmse:23365.05632
# [734]	validation_0-rmse:23364.97406
# [735]	validation_0-rmse:23362.38543
# [736]	validation_0-rmse:23359.39766
# [737]	validation_0-rmse:23361.34672
# [738]	validation_0-rmse:23358.41653
# [739]	validation_0-rmse:23360.22558
# [740]	validation_0-rmse:23357.77404
# [741]	validation_0-rmse:23359.53729
# [742]	validation_0-rmse:23363.03307
# [743]	validation_0-rmse:23366.28486
# [744]	validation_0-rmse:23359.30125
# [745]	validation_0-rmse:23359.03051
# [746]	validation_0-rmse:23358.83705
# [747]	validation_0-rmse:23353.82616
# [748]	validation_0-rmse:23352.41419
# [749]	validation_0-rmse:23355.15884
# [750]	validation_0-rmse:23352.83237
# [751]	validation_0-rmse:23353.99746
# [752]	validation_0-rmse:23349.70789
# [753]	validation_0-rmse:23348.22405
# [754]	validation_0-rmse:23353.83342
# [755]	validation_0-rmse:23350.52696
# [756]	validation_0-rmse:23353.24755
# [834]	validation_0-rmse:23267.87427
# [835]	validation_0-rmse:23264.88533
# [836]	validation_0-rmse:23261.39022
# [837]	validation_0-rmse:23257.08187
# [838]	validation_0-rmse:23258.05737
# [839]	validation_0-rmse:23252.07210
# [840]	validation_0-rmse:23255.45376
# [841]	validation_0-rmse:23258.39446
# [842]	validation_0-rmse:23261.76096
# [843]	validation_0-rmse:23259.31707
# [844]	validation_0-rmse:23256.72217
# [845]	validation_0-rmse:23255.54481
# [846]	validation_0-rmse:23250.24409
# [847]	validation_0-rmse:23249.42384
# [848]	validation_0-rmse:23248.44576
# [849]	validation_0-rmse:23243.00908
# [850]	validation_0-rmse:23237.66625
# [851]	validation_0-rmse:23235.23412
# [852]	validation_0-rmse:23237.47157
# [853]	validation_0-rmse:23235.41476
# [854]	validation_0-rmse:23232.06692
# [855]	validation_0-rmse:23235.03028
# [856]	validation_0-rmse:23240.48200
# [857]	validation_0-rmse:23239.11602
# [858]	validation_0-rmse:23236.51131
# [859]	validation_0-rmse:23239.64752
# [860]	validation_0-rmse:23238.15873
# [861]	validation_0-rmse:23237.70321
# [862]	validation_0-rmse:23235.62292
# [863]	validation_0-rmse:23238.46107
# [864]	validation_0-rmse:23235.76887
# [865]	validation_0-rmse:23241.45970
# [866]	validation_0-rmse:23245.27877
# [867]	validation_0-rmse:23242.19412
# [868]	validation_0-rmse:23241.23010
# [869]	validation_0-rmse:23233.74736
# [870]	validation_0-rmse:23231.76030
# [871]	validation_0-rmse:23228.43397
# [872]	validation_0-rmse:23231.12961
# [873]	validation_0-rmse:23230.00772
# [874]	validation_0-rmse:23230.14739
# [875]	validation_0-rmse:23227.40995
# [876]	validation_0-rmse:23222.29568
# [877]	validation_0-rmse:23221.85799
# [878]	validation_0-rmse:23221.57842
# [879]	validation_0-rmse:23219.29389
# [880]	validation_0-rmse:23217.60547
# [881]	validation_0-rmse:23215.26023
# [882]	validation_0-rmse:23217.69540
# [883]	validation_0-rmse:23220.27884
# [884]	validation_0-rmse:23216.58926
# [885]	validation_0-rmse:23213.90122
# [886]	validation_0-rmse:23210.07014
# [887]	validation_0-rmse:23211.55182
# [888]	validation_0-rmse:23209.68999
# [889]	validation_0-rmse:23213.17694
# [890]	validation_0-rmse:23214.59571
# [891]	validation_0-rmse:23211.43379
# [892]	validation_0-rmse:23207.18219
# [893]	validation_0-rmse:23206.05787
# [894]	validation_0-rmse:23203.37796
# [895]	validation_0-rmse:23200.54309
# [896]	validation_0-rmse:23199.88202
# [897]	validation_0-rmse:23197.71125
# [898]	validation_0-rmse:23193.85284
# [899]	validation_0-rmse:23192.01245
# [900]	validation_0-rmse:23190.09482
# [901]	validation_0-rmse:23187.92108
# [902]	validation_0-rmse:23185.48002
# [903]	validation_0-rmse:23189.97476
# [904]	validation_0-rmse:23186.50647
# [905]	validation_0-rmse:23186.22806
# [906]	validation_0-rmse:23185.92446
# [907]	validation_0-rmse:23184.12098
# [908]	validation_0-rmse:23181.21528
# [909]	validation_0-rmse:23179.41465
# [910]	validation_0-rmse:23176.35606
# [911]	validation_0-rmse:23174.33629
# [912]	validation_0-rmse:23171.88269
# [913]	validation_0-rmse:23170.77464
# [914]	validation_0-rmse:23174.07521
# [915]	validation_0-rmse:23170.57253
# [916]	validation_0-rmse:23171.74518
# [917]	validation_0-rmse:23171.81955
# [918]	validation_0-rmse:23175.58136
# [919]	validation_0-rmse:23174.36620
# [920]	validation_0-rmse:23169.44301
# [921]	validation_0-rmse:23167.37554
# [922]	validation_0-rmse:23169.59414
# [923]	validation_0-rmse:23167.74329
# [924]	validation_0-rmse:23167.04250
# [925]	validation_0-rmse:23168.68560
# [926]	validation_0-rmse:23170.62824
# [927]	validation_0-rmse:23170.34284
# [928]	validation_0-rmse:23173.09654
# [929]	validation_0-rmse:23170.82769
# [930]	validation_0-rmse:23170.24559
# [931]	validation_0-rmse:23168.74947
# [932]	validation_0-rmse:23167.39928
# [933]	validation_0-rmse:23164.04413
# [934]	validation_0-rmse:23162.72854
# [935]	validation_0-rmse:23160.26165
# [936]	validation_0-rmse:23159.06791
# [937]	validation_0-rmse:23158.56773
# [938]	validation_0-rmse:23154.93965
# [939]	validation_0-rmse:23154.14793
# [940]	validation_0-rmse:23156.79647
# [941]	validation_0-rmse:23155.93080
# [942]	validation_0-rmse:23158.90441
# [943]	validation_0-rmse:23157.63333
# [944]	validation_0-rmse:23158.93290
# [945]	validation_0-rmse:23157.32785
# [946]	validation_0-rmse:23158.97115
# [947]	validation_0-rmse:23156.32139
# [948]	validation_0-rmse:23154.93075
# [949]	validation_0-rmse:23154.21946
# [950]	validation_0-rmse:23154.65495
# [951]	validation_0-rmse:23151.63395
# [952]	validation_0-rmse:23152.79767
# [953]	validation_0-rmse:23153.52621
# [954]	validation_0-rmse:23152.45664
# [955]	validation_0-rmse:23150.87529
# [956]	validation_0-rmse:23149.32288
# [957]	validation_0-rmse:23147.61849
# [958]	validation_0-rmse:23148.15811
# [959]	validation_0-rmse:23150.06531
# [960]	validation_0-rmse:23149.81898
# [961]	validation_0-rmse:23146.44002
# [962]	validation_0-rmse:23144.90356
# [963]	validation_0-rmse:23141.95260
# [964]	validation_0-rmse:23141.89699
# [965]	validation_0-rmse:23139.02403
# [966]	validation_0-rmse:23137.87454
# [967]	validation_0-rmse:23138.27746
# [968]	validation_0-rmse:23135.79460
# [969]	validation_0-rmse:23138.26634
# [970]	validation_0-rmse:23134.78654
# [971]	validation_0-rmse:23136.86369
# [972]	validation_0-rmse:23134.44706
# [973]	validation_0-rmse:23128.82551
# [974]	validation_0-rmse:23126.94220
# [975]	validation_0-rmse:23126.56132
# [976]	validation_0-rmse:23129.62230
# [977]	validation_0-rmse:23127.80686
# [978]	validation_0-rmse:23126.43700
# [979]	validation_0-rmse:23130.24214
# [980]	validation_0-rmse:23128.67720
# [981]	validation_0-rmse:23127.47791
# [982]	validation_0-rmse:23128.19982
# [983]	validation_0-rmse:23129.07364
# [984]	validation_0-rmse:23128.57425
# [985]	validation_0-rmse:23127.79679
# [986]	validation_0-rmse:23126.34574
# [987]	validation_0-rmse:23124.93400
# [988]	validation_0-rmse:23123.38654
# [989]	validation_0-rmse:23122.05884
# [990]	validation_0-rmse:23120.29375
# [991]	validation_0-rmse:23119.18766
# [992]	validation_0-rmse:23115.50276
# [993]	validation_0-rmse:23113.94309
# [994]	validation_0-rmse:23114.91155
# [995]	validation_0-rmse:23118.32579
# [996]	validation_0-rmse:23117.49270
# [997]	validation_0-rmse:23117.27001
# [998]	validation_0-rmse:23115.35060
# [999]	validation_0-rmse:23115.62857
# Root Mean Squared Error: 23115.62832384012

# %%
print(X.shape)
# Out:
# (20000, 55)

# %%
from xgboost import XGBRegressor

# # 创建XGBoost模型
model = XGBRegressor(
    # 基本参数
    n_estimators=1000,        # 树的数量
    max_depth=6,              # 树的最大深度，避免过拟合
    learning_rate=0.01,       # 较小的学习率，提高模型稳定性
    
    # 防止过拟合的参数
    min_child_weight=5,       # 控制过拟合
    gamma=0.1,               # 节点分裂所需的最小损失函数下降值
    subsample=0.8,           # 随机采样训练样本的比例
    colsample_bytree=0.8,    # 随机采样特征的比例
    
    # 正则化参数
    reg_alpha=0.1,           # L1正则化
    reg_lambda=1,            # L2正则化
    
    # 其他参数
    objective='reg:squarederror',  # 回归任务
    random_state=42,
    n_jobs=-1,               # 使用所有CPU核心
    verbosity=0
)


# Assuming 'data' is your DataFrame and 'target' is the name of your target variable
X = X_train_combined  # Features
y = y_train       # Target variable

# 添加早停以防止过拟合
eval_set = [(X_valid_combined, y_valid)]

model.fit(
    X, 
    y,
    eval_set=eval_set
)

# Making predictions
y_valid_pred = model.predict(X_valid_combined)

# Calculating the performance metrics
mse = mean_squared_error(y_valid_pred, y_valid)
r2 = r2_score(y_valid_pred, y_valid)
# Calculating the RMSE
rmse = math.sqrt(mse)

# Printing the MSE, RMSE, and R² Score
# print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# print(f'R² Score: {r2}')
# Out:
# [0]	validation_0-rmse:142304.07000
# [1]	validation_0-rmse:141070.90840
# [2]	validation_0-rmse:139850.11163
# [3]	validation_0-rmse:138635.34909
# [4]	validation_0-rmse:137413.74532
# [5]	validation_0-rmse:136200.11569
# [6]	validation_0-rmse:135015.83951
# [7]	validation_0-rmse:133828.09749
# [8]	validation_0-rmse:132654.29774
# [9]	validation_0-rmse:131512.37989
# [10]	validation_0-rmse:130406.14831
# [11]	validation_0-rmse:129267.90975
# [12]	validation_0-rmse:128167.66247
# [13]	validation_0-rmse:127052.09616
# [14]	validation_0-rmse:125948.28683
# [15]	validation_0-rmse:124901.23939
# [16]	validation_0-rmse:123822.26874
# [17]	validation_0-rmse:122749.74898
# [18]	validation_0-rmse:121698.12703
# [19]	validation_0-rmse:120638.44192
# [20]	validation_0-rmse:119622.55289
# [21]	validation_0-rmse:118594.76998
# [22]	validation_0-rmse:117583.45341
# [23]	validation_0-rmse:116540.42821
# [24]	validation_0-rmse:115542.41204
# [25]	validation_0-rmse:114562.80921
# [331]	validation_0-rmse:24776.02132
# [332]	validation_0-rmse:24749.60591
# [333]	validation_0-rmse:24711.39065
# [334]	validation_0-rmse:24665.43918
# [335]	validation_0-rmse:24634.02285
# [336]	validation_0-rmse:24613.27999
# [337]	validation_0-rmse:24576.97257
# [338]	validation_0-rmse:24549.78334
# [339]	validation_0-rmse:24522.72810
# [340]	validation_0-rmse:24492.06334
# [341]	validation_0-rmse:24472.97376
# [342]	validation_0-rmse:24445.87183
# [343]	validation_0-rmse:24408.56047
# [344]	validation_0-rmse:24381.98058
# [345]	validation_0-rmse:24359.45971
# [346]	validation_0-rmse:24336.77956
# [347]	validation_0-rmse:24306.23086
# [348]	validation_0-rmse:24277.04331
# [349]	validation_0-rmse:24229.81376
# [350]	validation_0-rmse:24209.91323
# [351]	validation_0-rmse:24186.18905
# [352]	validation_0-rmse:24159.06504
# [353]	validation_0-rmse:24142.57943
# [354]	validation_0-rmse:24116.18664
# [355]	validation_0-rmse:24072.71057
# [356]	validation_0-rmse:24058.55404
# [357]	validation_0-rmse:24037.80426
# [358]	validation_0-rmse:24014.71308
# [359]	validation_0-rmse:23995.12868
# [360]	validation_0-rmse:23970.18901
# [361]	validation_0-rmse:23950.23094
# [362]	validation_0-rmse:23928.56634
# [363]	validation_0-rmse:23903.15553
# [364]	validation_0-rmse:23865.24431
# [365]	validation_0-rmse:23844.12151
# [366]	validation_0-rmse:23808.61255
# [367]	validation_0-rmse:23793.70700
# [368]	validation_0-rmse:23770.01370
# [369]	validation_0-rmse:23753.19147
# [370]	validation_0-rmse:23725.92069
# [371]	validation_0-rmse:23708.63691
# [372]	validation_0-rmse:23687.12698
# [373]	validation_0-rmse:23665.58016
# [374]	validation_0-rmse:23650.03055
# [375]	validation_0-rmse:23629.30306
# [376]	validation_0-rmse:23618.64982
# [377]	validation_0-rmse:23591.56617
# [378]	validation_0-rmse:23572.78155
# [379]	validation_0-rmse:23548.61562
# [380]	validation_0-rmse:23527.35605
# [381]	validation_0-rmse:23503.52450
# [382]	validation_0-rmse:23485.27059
# [383]	validation_0-rmse:23471.04863
# [384]	validation_0-rmse:23451.01275
# [385]	validation_0-rmse:23437.88549
# [386]	validation_0-rmse:23414.16707
# [387]	validation_0-rmse:23403.53762
# [388]	validation_0-rmse:23387.60053
# [389]	validation_0-rmse:23376.40080
# [390]	validation_0-rmse:23349.04381
# [391]	validation_0-rmse:23338.33640
# [392]	validation_0-rmse:23324.55653
# [393]	validation_0-rmse:23308.55266
# [394]	validation_0-rmse:23288.79772
# [395]	validation_0-rmse:23276.52179
# [396]	validation_0-rmse:23262.54936
# [397]	validation_0-rmse:23241.04621
# [398]	validation_0-rmse:23223.40476
# [399]	validation_0-rmse:23208.68475
# [400]	validation_0-rmse:23196.45377
# [401]	validation_0-rmse:23192.04984
# [402]	validation_0-rmse:23183.37991
# [403]	validation_0-rmse:23174.64680
# [404]	validation_0-rmse:23157.87457
# [405]	validation_0-rmse:23147.01723
# [406]	validation_0-rmse:23120.76542
# [940]	validation_0-rmse:21206.80056
# [941]	validation_0-rmse:21205.91595
# [942]	validation_0-rmse:21203.09670
# [943]	validation_0-rmse:21200.05459
# [944]	validation_0-rmse:21198.99130
# [945]	validation_0-rmse:21199.21487
# [946]	validation_0-rmse:21198.87976
# [947]	validation_0-rmse:21198.71017
# [948]	validation_0-rmse:21196.64965
# [949]	validation_0-rmse:21195.36497
# [950]	validation_0-rmse:21192.51536
# [951]	validation_0-rmse:21189.93963
# [952]	validation_0-rmse:21187.06884
# [953]	validation_0-rmse:21185.76109
# [954]	validation_0-rmse:21184.05791
# [955]	validation_0-rmse:21181.67150
# [956]	validation_0-rmse:21183.04561
# [957]	validation_0-rmse:21181.33686
# [958]	validation_0-rmse:21176.96484
# [959]	validation_0-rmse:21176.18650
# [960]	validation_0-rmse:21175.11058
# [961]	validation_0-rmse:21174.00489
# [962]	validation_0-rmse:21174.76867
# [963]	validation_0-rmse:21175.33802
# [964]	validation_0-rmse:21174.41942
# [965]	validation_0-rmse:21172.93083
# [966]	validation_0-rmse:21169.20915
# [967]	validation_0-rmse:21166.85353
# [968]	validation_0-rmse:21165.69858
# [969]	validation_0-rmse:21161.82793
# [970]	validation_0-rmse:21162.50554
# [971]	validation_0-rmse:21158.59920
# [972]	validation_0-rmse:21156.09048
# [973]	validation_0-rmse:21153.19404
# [974]	validation_0-rmse:21152.98549
# [975]	validation_0-rmse:21150.07227
# [976]	validation_0-rmse:21151.83546
# [977]	validation_0-rmse:21150.06896
# [978]	validation_0-rmse:21150.09591
# [979]	validation_0-rmse:21147.94736
# [980]	validation_0-rmse:21148.41026
# [981]	validation_0-rmse:21149.28184
# [982]	validation_0-rmse:21148.01132
# [983]	validation_0-rmse:21147.17576
# [984]	validation_0-rmse:21148.58541
# [985]	validation_0-rmse:21148.47931
# [986]	validation_0-rmse:21145.75028
# [987]	validation_0-rmse:21141.74463
# [988]	validation_0-rmse:21140.39815
# [989]	validation_0-rmse:21140.04693
# [990]	validation_0-rmse:21138.05535
# [991]	validation_0-rmse:21136.66602
# [992]	validation_0-rmse:21135.27988
# [993]	validation_0-rmse:21134.65602
# [994]	validation_0-rmse:21130.93235
# [995]	validation_0-rmse:21128.17954
# [996]	validation_0-rmse:21126.12568
# [997]	validation_0-rmse:21128.63731
# [998]	validation_0-rmse:21126.69268
# [999]	validation_0-rmse:21125.49765
# Root Mean Squared Error: 21125.498034575146

# %%
# 获取UMAP降维后的维度
n_umap_components = bert_train_umap.shape[1]

# 动态生成特征名称
feature_names = cat_nu_cols + [f'bert_{i}' for i in range(n_umap_components)]

# 分析特征重要性
feature_importance = model.feature_importances_
importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importance
}).sort_values('importance', ascending=False)

print("Top 20 most important features:")
print(importance_df.head(20))
# Out:
# Top 20 most important features:
#                         feature  importance
# 11                          arf    0.477349
# 8                   dereg_value    0.148598
# 2                         power    0.055554
# 31                rare & exotic    0.046303
# 5                  depreciation    0.032690
# 14       text_model_value_score    0.029590
# 53                         year    0.021942
# 0                  manufactured    0.016567
# 9                       mileage    0.013162
# 10                          omv    0.011638
# 17       text_performance_score    0.011587
# 12          make_target_encoded    0.009782
# 3                    engine_cap    0.008250
# 6                           coe    0.007900
# 21                      coe car    0.007849
# 1                   curb_weight    0.007662
# 13  text_brand_popularity_score    0.006509
# 26        imported used vehicle    0.006269
# 43          type_of_vehicle_suv    0.005629
# 59                       bert_4    0.005016

# %%
import lightgbm as lgb
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.ensemble import StackingRegressor
from xgboost import XGBRegressor

# 1. LightGBM
lgb_model = lgb.LGBMRegressor(
    n_estimators=1000,
    learning_rate=0.01,
    num_leaves=31,
    max_depth=6,
    min_child_samples=20,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    verbose=-1
)

# 2. CatBoost
cat_model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.01,
    depth=6,
    l2_leaf_reg=3,
    random_seed=42,
    verbose=False
)

# 3. Stacking
base_models = [
    ('xgb', XGBRegressor(verbosity=0, random_state=42)),
    ('lgb', lgb.LGBMRegressor(verbose=-1, random_state=42)),
    ('cat', CatBoostRegressor(verbose=False, random_seed=42))
]
stacking = StackingRegressor(
    estimators=base_models,
    final_estimator=lgb.LGBMRegressor(verbose=-1),
    cv=5
)

# 4. RandomForest
rf_model = RandomForestRegressor(
    n_estimators=200,
    max_depth=15,
    min_samples_split=5,
    min_samples_leaf=2,
    n_jobs=-1,
    random_state=42
)

# 5. GradientBoosting
gb_model = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    min_samples_split=5,
    random_state=42
)

# 比较函数
def compare_models(models, X_train, y_train, X_valid, y_valid):
    results = []
    for name, model in models.items():
        print(f"训练 {name}")
        model.fit(X_train, y_train)
        y_pred = model.predict(X_valid)
        rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
        r2 = r2_score(y_valid, y_pred)
        results.append({
            'Model': name,
            'RMSE': rmse,
            'R2': r2
        })
    return pd.DataFrame(results).sort_values('RMSE')

# 比较所有模型
models = {
    'LightGBM': lgb_model,
    'CatBoost': cat_model,
    'Stacking': stacking,
    'RandomForest': rf_model,
    'GradientBoosting': gb_model,
    'XGBoost': model  # 之前定义的XGBoost模型
}

# 使用cat_log_cols特征集（通常对价格预测效果更好）
results = compare_models(models, X_train_combined, y_train, 
                       X_valid_combined, y_valid)
print("\n模型性能比较:")
print(results)
# Out:
# 训练 LightGBM
# c:\Users\10021\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 训练 CatBoost
# 训练 Stacking
# c:\Users\10021\anaconda3\Lib\site-packages\sklearn\ensemble\_stacking.py:967: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 训练 RandomForest
# c:\Users\10021\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 训练 GradientBoosting
# c:\Users\10021\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# 训练 XGBoost
#
# 模型性能比较:
#               Model          RMSE        R2
# 5           XGBoost  21125.498035  0.978335
# 0          LightGBM  23376.952277  0.973471
# 1          CatBoost  26803.513922  0.965124
# 2          Stacking  28623.545339  0.960227
# 3      RandomForest  28880.523994  0.959509
# 4  GradientBoosting  29576.333096  0.957535

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

def objective(trial):
    """Optuna目标函数，用于优化XGBoost参数"""
    param = {
        # 基本参数
        'n_estimators': trial.suggest_int('n_estimators', 100, 5000),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.3, log=True),
        
        # 防止过拟合的参数
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'gamma': trial.suggest_float('gamma', 1e-4, 2.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        
        # 正则化参数
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-4, 20.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-4, 20.0, log=True),
        
        # 固定参数
        'objective': 'reg:squarederror',
        'random_state': 42,
        'n_jobs': -1,
        'verbosity': 0
    }
    
    # 创建模型
    model = XGBRegressor(**param)
    
    try:
        # 训练模型
        model.fit(X_train_combined, y_train.values.ravel())
        
        # 预测验证集
        y_pred = model.predict(X_valid_combined)
        
        # 计算RMSE
        rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
        return rmse
        
    except Exception as e:
        print(f"训练出错: {str(e)}")
        return float('inf')

# 创建Optuna study
study = optuna.create_study(direction='minimize')

# 运行优化
print("开始Optuna参数优化...")
study.optimize(objective, n_trials=200, show_progress_bar=True)

# 打印最佳参数
print("\n最佳参数:")
for key, value in study.best_params.items():
    print(f"{key}: {value}")
print(f"\n最佳RMSE: {study.best_value:.4f}")

# 使用最佳参数创建最终模型
best_params = study.best_params
best_params.update({
    'objective': 'reg:squarederror',
    'random_state': 42,
    'n_jobs': -1,
    'verbosity': 0
})

# 创建并训练最终模型
final_model = XGBRegressor(**best_params)
final_model.fit(X_train_combined, y_train.values.ravel())

# 评估最终模型
y_pred = final_model.predict(X_valid_combined)
final_rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
print(f"\n最终模型在验证集上的RMSE: {final_rmse:.4f}")

# 更新模型字典
if 'models' not in locals():
    models = {}
models['XGBoost (Optimized)'] = final_model
# Out:
# [I 2024-11-10 07:31:58,802] A new study created in memory with name: no-name-e97a7e1f-a633-4c8e-a6a1-4b7d3abc7f70
# 开始Optuna参数优化...
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2024-11-10 07:32:20,534] Trial 0 finished with value: 24166.919581459733 and parameters: {'n_estimators': 3342, 'max_depth': 10, 'learning_rate': 0.23191815854401865, 'min_child_weight': 12, 'gamma': 0.0005997587641445995, 'subsample': 0.9705746590953102, 'colsample_bytree': 0.6225434167664557, 'reg_alpha': 3.734630132665368, 'reg_lambda': 1.7204287895256785}. Best is trial 0 with value: 24166.919581459733.
# [I 2024-11-10 07:32:22,301] Trial 1 finished with value: 25304.40033890315 and parameters: {'n_estimators': 311, 'max_depth': 10, 'learning_rate': 0.01685980455279082, 'min_child_weight': 16, 'gamma': 0.001026335292945043, 'subsample': 0.7566267104914737, 'colsample_bytree': 0.6924612386438889, 'reg_alpha': 0.0029961056971225964, 'reg_lambda': 9.552722843005865}. Best is trial 0 with value: 24166.919581459733.
# [I 2024-11-10 07:32:27,158] Trial 2 finished with value: 20981.076831211187 and parameters: {'n_estimators': 578, 'max_depth': 14, 'learning_rate': 0.02912264101388001, 'min_child_weight': 11, 'gamma': 0.33530073527770354, 'subsample': 0.8467632346578379, 'colsample_bytree': 0.6002472767141595, 'reg_alpha': 0.8463385547765139, 'reg_lambda': 0.0029518941142115404}. Best is trial 2 with value: 20981.076831211187.
# [I 2024-11-10 07:32:38,110] Trial 3 finished with value: 21296.678453096993 and parameters: {'n_estimators': 2895, 'max_depth': 8, 'learning_rate': 0.034092398427545634, 'min_child_weight': 6, 'gamma': 0.11862761957964423, 'subsample': 0.40626586923044633, 'colsample_bytree': 0.7557156888474841, 'reg_alpha': 2.8777793925101176, 'reg_lambda': 0.00029289171288371466}. Best is trial 2 with value: 20981.076831211187.
# [I 2024-11-10 07:32:46,760] Trial 4 finished with value: 23541.41212353531 and parameters: {'n_estimators': 1893, 'max_depth': 7, 'learning_rate': 0.13941514380796577, 'min_child_weight': 1, 'gamma': 0.0023620519802565305, 'subsample': 0.5723745994183759, 'colsample_bytree': 0.797341587892785, 'reg_alpha': 5.801205236044197, 'reg_lambda': 0.0059740736300357795}. Best is trial 2 with value: 20981.076831211187.
# [I 2024-11-10 07:32:55,473] Trial 5 finished with value: 21886.56201401933 and parameters: {'n_estimators': 4530, 'max_depth': 4, 'learning_rate': 0.12779671055636, 'min_child_weight': 8, 'gamma': 0.00020538334740470096, 'subsample': 0.7739921624276123, 'colsample_bytree': 0.7353313369735444, 'reg_alpha': 0.004528927134004779, 'reg_lambda': 2.1764082335209687}. Best is trial 2 with value: 20981.076831211187.
# [I 2024-11-10 07:33:03,705] Trial 6 finished with value: 114211.57018372523 and parameters: {'n_estimators': 789, 'max_depth': 14, 'learning_rate': 0.00036976670833619964, 'min_child_weight': 6, 'gamma': 0.004652088713931806, 'subsample': 0.7020843177905807, 'colsample_bytree': 0.44547129919599515, 'reg_alpha': 0.0003224233893762938, 'reg_lambda': 5.9756009987978835}. Best is trial 2 with value: 20981.076831211187.
# [I 2024-11-10 07:33:32,213] Trial 7 finished with value: 22728.96520419049 and parameters: {'n_estimators': 4960, 'max_depth': 11, 'learning_rate': 0.14811466341230545, 'min_child_weight': 20, 'gamma': 0.447113008347501, 'subsample': 0.8574097384990569, 'colsample_bytree': 0.9584191832235844, 'reg_alpha': 0.6496325191419903, 'reg_lambda': 0.10356550000057044}. Best is trial 2 with value: 20981.076831211187.
# [I 2024-11-10 07:35:36,290] Trial 8 finished with value: 24497.081844680128 and parameters: {'n_estimators': 4599, 'max_depth': 15, 'learning_rate': 0.0006468490534655622, 'min_child_weight': 7, 'gamma': 0.0002735973038716429, 'subsample': 0.5691995451846789, 'colsample_bytree': 0.790540452398578, 'reg_alpha': 0.26998010375559106, 'reg_lambda': 0.061407716884857626}. Best is trial 2 with value: 20981.076831211187.
# [I 2024-11-10 07:35:48,427] Trial 9 finished with value: 51266.29399217776 and parameters: {'n_estimators': 3006, 'max_depth': 8, 'learning_rate': 0.00046103820064649745, 'min_child_weight': 17, 'gamma': 0.0027419389207348176, 'subsample': 0.8442928111822144, 'colsample_bytree': 0.6066738170045596, 'reg_alpha': 0.028435198508053247, 'reg_lambda': 2.7292072296546026}. Best is trial 2 with value: 20981.076831211187.
. Best is trial 11 with value: 19084.124124252252.
# [I 2024-11-10 07:58:07,959] Trial 96 finished with value: 20819.3775099511 and parameters: {'n_estimators': 2916, 'max_depth': 6, 'learning_rate': 0.029950024291962304, 'min_child_weight': 8, 'gamma': 0.0004072121483454568, 'subsample': 0.45007951416820446, 'colsample_bytree': 0.5334830057985775, 'reg_alpha': 0.0010641224170948628, 'reg_lambda': 0.0003226212638909594}. Best is trial 11 with value: 19084.124124252252.
# [I 2024-11-10 07:58:20,805] Trial 97 finished with value: 21192.940963294735 and parameters: {'n_estimators': 3242, 'max_depth': 7, 'learning_rate': 0.07150914023479779, 'min_child_weight': 11, 'gamma': 0.0031975605852469454, 'subsample': 0.49499993066277875, 'colsample_bytree': 0.6835069596139709, 'reg_alpha': 0.001641738647225965, 'reg_lambda': 0.8540146579967013}. Best is trial 11 with value: 19084.124124252252.
# [W 2024-11-10 07:58:45,490] Trial 98 failed with parameters: {'n_estimators': 4942, 'max_depth': 11, 'learning_rate': 0.014709856567007788, 'min_child_weight': 5, 'gamma': 0.04890373667346294, 'subsample': 0.5078650957940998, 'colsample_bytree': 0.5813640941784978, 'reg_alpha': 0.0007639848093453844, 'reg_lambda': 0.0005388003603936975} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\10021\anaconda3\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\10021\AppData\Local\Temp\ipykernel_100804\3189747262.py", line 36, in objective
#     model.fit(X_train_combined, y_train.values.ravel())
#   File "c:\Users\10021\anaconda3\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\10021\anaconda3\Lib\site-packages\xgboost\sklearn.py", line 1108, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "c:\Users\10021\anaconda3\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\10021\anaconda3\Lib\site-packages\xgboost\training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "c:\Users\10021\anaconda3\Lib\site-packages\xgboost\core.py", line 2101, in update
#     _LIB.XGBoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2024-11-10 07:58:45,501] Trial 98 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 54
#      52 # 运行优化
#      53 print("开始Optuna参数优化...")
# ---> 54 study.optimize(objective, n_trials=200, show_progress_bar=True)
#      56 # 打印最佳参数
#      57 print("\n最佳参数:")
#
# File c:\Users\10021\anaconda3\Lib\site-packages\optuna\study\study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File c:\Users\10021\anaconda3\Lib\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File c:\Users\10021\anaconda3\Lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File c:\Users\10021\anaconda3\Lib\site-packages\optuna\study\_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File c:\Users\10021\anaconda3\Lib\site-packages\optuna\study\_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[16], line 36, in objective(trial)
#      32 model = XGBRegressor(**param)
#      34 try:
#      35     # 训练模型
# ---> 36     model.fit(X_train_combined, y_train.values.ravel())
#      38     # 预测验证集
#      39     y_pred = model.predict(X_valid_combined)
#
# File c:\Users\10021\anaconda3\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\10021\anaconda3\Lib\site-packages\xgboost\sklearn.py:1108, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1105     obj = None
#    1107 model, metric, params = self._configure_fit(xgb_model, params)
# -> 1108 self._Booster = train(
#    1109     params,
#    1110     train_dmatrix,
#    1111     self.get_num_boosting_rounds(),
#    1112     evals=evals,
#    1113     early_stopping_rounds=self.early_stopping_rounds,
#    1114     evals_result=evals_result,
#    1115     obj=obj,
#    1116     custom_metric=metric,
#    1117     verbose_eval=verbose,
#    1118     xgb_model=model,
#    1119     callbacks=self.callbacks,
#    1120 )
#    1122 self._set_evaluation_result(evals_result)
#    1123 return self
#
# File c:\Users\10021\anaconda3\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\10021\anaconda3\Lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\10021\anaconda3\Lib\site-packages\xgboost\core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# 使用最佳参数创建最终模型
# best_model = XGBRegressor(
#     n_estimators=4163,
#     max_depth=6, 
#     learning_rate=0.0110604556318349,
#     min_child_weight=3,
#     gamma=0.0036210695281719447,
#     subsample=0.6453444676549167,
#     colsample_bytree=0.6761141085642669,
#     reg_alpha=0.34592583966227625,
#     reg_lambda=0.01554727012065511,
#     objective='reg:squarederror',
#     random_state=42,
#     n_jobs=-1,
#     verbosity=0
# )

best_model = XGBRegressor(
    n_estimators=10000,
    max_depth=6, 
    learning_rate=0.0110604556318349,
    min_child_weight=3,
    gamma=0.0036210695281719447,
    subsample=0.6453444676549167,
    colsample_bytree=0.6761141085642669,
    reg_alpha=0.34592583966227625,
    reg_lambda=0.01554727012065511,
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1,
    verbosity=0
)

# 创建并训练最终模型
best_model.fit(X_train_combined, y_train.values.ravel())

# 评估最终模型
y_pred = best_model.predict(X_valid_combined)
final_rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
print(f"\n最终模型在验证集上的RMSE: {final_rmse:.4f}")
# Out:
# 最终模型在验证集上的RMSE: 19577.2006

# %%
print("生成验证集预测结果...")
valid_predictions = best_model.predict(X_valid_combined)
valid_predictions_df = pd.DataFrame({
    'Id': range(len(valid_predictions)),
    'Predicted': valid_predictions
})
valid_predictions_df.to_csv('data/ml_valid.csv', index=False)
print("验证集预测结果已保存到 data/ml_valid.csv")

print("生成测试集预测结果...")
test_predictions = best_model.predict(X_test_combined)
test_predictions_df = pd.DataFrame({
    'Id': range(len(test_predictions)),
    'Predicted': test_predictions
})
test_predictions_df.to_csv('data/ml_test.csv', index=False)
print("测试集预测结果已保存到 data/ml_test.csv")
# Out:
# 生成验证集预测结果...
# 验证集预测结果已保存到 data/ml_valid.csv
# 生成测试集预测结果...
# 测试集预测结果已保存到 data/ml_test.csv

# %% [markdown]
# ## Prediction on test set

# %%
print("使用全量数据训练最终模型...")
best_model.fit(X_train_full_combined, y_train_full)

print("生成测试集预测结果...")
test_predictions = best_model.predict(X_test_combined)

# 创建预测结果DataFrame
predictions_df = pd.DataFrame({
    'Id': range(len(test_predictions)),
    'Predicted': test_predictions
})

# 保存预测结果
predictions_df.to_csv('data/predictions.csv', index=False)
print("预测结果已保存到 data/predictions.csv")
# Out:
# 使用全量数据训练最终模型...
# 生成测试集预测结果...
# 预测结果已保存到 data/predictions.csv

# %%
print("生成验证集预测结果...")
valid_predictions = best_model.predict(X_valid_combined)
valid_predictions_df = pd.DataFrame({
    'Id': range(len(valid_predictions)),
    'Predicted': valid_predictions
})
valid_predictions_df.to_csv('data/full_ml_valid.csv', index=False)
print("验证集预测结果已保存到 data/full_ml_valid.csv")

print("生成测试集预测结果...")
test_predictions = best_model.predict(X_test_combined)
test_predictions_df = pd.DataFrame({
    'Id': range(len(test_predictions)),
    'Predicted': test_predictions
})
test_predictions_df.to_csv('data/full_ml_test.csv', index=False)
print("测试集预测结果已保存到 data/full_ml_test.csv")
# Out:
# 生成验证集预测结果...
# 验证集预测结果已保存到 data/full_ml_valid.csv
# 生成测试集预测结果...
# 测试集预测结果已保存到 data/full_ml_test.csv
